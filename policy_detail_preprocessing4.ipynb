# %%
import pymysql
import pandas as pd
import sqlalchemy
import logging
import re
from typing import Dict, List, Optional
from sqlalchemy import create_engine, types
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor

# %%
host= 
port =  
user = 
password = 
database = 'policy'

# %%
ST = datetime.now()
print(ST)
# Out:
# 2024-11-12 23:49:30.823777

# %%
class PolicyDataProcessor:
    def __init__(self, db_config: Dict):
        """
        데이터베이스 설정 및 로깅 초기화
        """
        self.db_config = db_config
        self.engine = create_engine(
            f"mysql+pymysql://{db_config['user']}:{db_config['password']}@"
            f"{db_config['host']}:{db_config.get('port', 3306)}/{db_config['database']}"
        )
        
        logging.basicConfig(
            level=logging.DEBUG,
            format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
        )
        
        self.keywords = {
            'target': [
                '지원대상[\\s]*:?[\\s]*',
                '대상[\\s]*:?[\\s]*',
                '신청대상[\\s]*:?[\\s]*',
                '참여대상[\\s]*:?[\\s]*',
                '모집대상[\\s]*:?[\\s]*',
                '구직[\\s]*:?[\\s]*',
                '출산[\\s]*:?[\\s]*'
            ],
            'condition': ['자격', '요건', '조건', '기준', '신청자격'],
            'support': ['지원내용', '지원금액', '지원한도', '지원규모', '사업내용', '지원사항'],
            'apply_method': ['신청방법', '접수방법', '지원방법', '신청절차', '신청기간'],
            'contact': ['문의처', '담당자', '연락처', '문의', '전화'],
            'url': ['http', 'www']
        }

    def connect_db(self):
        """데이터베이스 연결"""
        try:
            conn = pymysql.connect(**self.db_config)
            logging.info("Successfully connected to database")
            return conn
        except Exception as e:
            logging.error(f"Database connection error: {e}")
            raise

    def fetch_data(self) -> pd.DataFrame:
        """RDS에서 데이터 가져오기"""
        try:
            query = "SELECT * FROM policy_detail"
            df = pd.read_sql(query, self.engine)
            logging.info(f"Successfully fetched {len(df)} records from database")
            return df
        except Exception as e:
            logging.error(f"Error fetching data: {e}")
            raise

    def clean_text(self, text: Optional[str]) -> str:
        """
        텍스트 클리닝
        """
        if pd.isna(text):
            return ""
        
        text = re.sub(r'<[^>]+>', '', str(text))
        text = re.sub(r'[■▶▪●★※◦○●:*ㅁ★▶◀\-\*o□❍]', ' ', text)
        text = re.sub(r'\s+', ' ', text).strip()
        return text

    def extract_field(self, text: str, keywords: List[str]) -> str:
        """
        주어진 키워드를 기반으로 텍스트에서 관련 정보 추출
        """
        text = self.clean_text(text)
        
        for keyword in keywords:
            pattern = f"{keyword}(.*?)(?=신청방법|제외대상|$)"
            matches = re.findall(pattern, text, re.DOTALL | re.IGNORECASE)
            if matches:
                extracted_text = matches[0].strip()
                if len(extracted_text) > 0:
                    cleaned_text = self.clean_text(extracted_text)
                    return cleaned_text.lstrip(',').strip()  # 맨 앞의 콤마 제거
        return ""

    def parse_policy(self, row: Dict) -> Dict:
        """
        정책 데이터 파싱
        빈 문자열도 clean_text 처리
        """
        logging.info(f"Processing row idx: {row.get('idx')}")
        logging.info(f"Original target: {row.get('target')}")
        
        combined_text = "\n".join([
            str(row.get(field, "")) 
            for field in ['subject', 'condition', 'way']
        ])
        
        # target 정보 추출 시도
        target_info = self.extract_field(combined_text, self.keywords['target'])
        logging.info(f"Initially extracted target: {target_info}")
        
        # target 정보가 유효한지 철저히 체크
        if not target_info or target_info.isspace() or target_info == "" or len(target_info.strip()) == 0:
            original_target = row.get('target', '')
            logging.info(f"Using original target: {original_target}")
            
            if not pd.isna(original_target):  # None이 아닌 모든 값에 대해 clean_text 적용
                target_info = self.clean_text(original_target)
                logging.info(f"After cleaning original target: {target_info}")
        
        # 여전히 target_info가 없으면 subject 사용
        if not target_info or target_info.isspace() or target_info == "" or len(target_info.strip()) == 0:
            subject = row.get('subject', '')
            if not pd.isna(subject):  # None이 아닌 모든 값에 대해 clean_text 적용
                target_info = self.clean_text(subject)  # subject도 clean_text 처리
                logging.info(f"Using cleaned subject as target: {target_info}")
        
        logging.info(f"Final target value: {target_info}")
        
        return {
            'idx': row.get('idx', None),
            'target': target_info,
            'condition': self.extract_field(combined_text, self.keywords['condition']) or row.get('condition', ''),
            'content': row.get('content', ''),
            'scale': self.clean_text(row.get('scale', '')),
            'enquiry': self.clean_text(row.get('enquiry', '')),
            'url': row.get('document', row.get('url', ''))
        }

    def process_data(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        데이터프레임 처리
        """
        results = []
        for _, row in df.iterrows():
            parsed_data = self.parse_policy(row.to_dict())
            results.append(parsed_data)
        
        result_df = pd.DataFrame(results)
        logging.info(f"Successfully processed {len(result_df)} records")
        return result_df

    def save_to_db(self, df: pd.DataFrame, table_name='policy_detail_cleaned') -> None:
        """
        처리된 데이터를 RDS에 저장
        """
        try:
            df['idx'] = df['idx'].astype(int)
            df.to_sql(
                name=table_name,
                con=self.engine,
                index=False,
                if_exists='replace',
                chunksize=1000,
                dtype={'idx': types.BigInteger}
            )
            logging.info(f"Successfully saved {len(df)} records to {table_name}")
        except Exception as e:
            logging.error(f"Error saving data: {e}")
            raise

def main():
    db_config = {
        'host': host,
        'user': user,
        'password': password,
        'database': database
    }
    
    try:
        processor = PolicyDataProcessor(db_config)
        
        df = processor.fetch_data()
        
        processed_df = processor.process_data(df)
        
        processor.save_to_db(processed_df)
        
        logging.info("Data processing completed successfully")
        
    except Exception as e:
        logging.error(f"Error in main process: {e}")
        raise

if __name__ == "__main__":
    main()
# Out:
# 2024-11-13 02:01:47,356 - root - INFO - Successfully fetched 111 records from database
# 2024-11-13 02:01:47,357 - root - INFO - Processing row idx: 1
# 2024-11-13 02:01:47,358 - root - INFO - Original target: None
# 2024-11-13 02:01:47,359 - root - INFO - Initially extracted target: 근로활동을 하는 19세 ~ 39세 청년 도내 중소·중견기업 면접자, 도내 중소·중견기업 생애 최초 취업자, 도내 중소·중견기업 1년 이상 근속자 gbw rk.kr 또는 청년애꿈수당.kr
# 2024-11-13 02:01:47,360 - root - INFO - Final target value: 근로활동을 하는 19세 ~ 39세 청년 도내 중소·중견기업 면접자, 도내 중소·중견기업 생애 최초 취업자, 도내 중소·중견기업 1년 이상 근속자 gbw rk.kr 또는 청년애꿈수당.kr
# 2024-11-13 02:01:47,362 - root - INFO - Processing row idx: 3
# 2024-11-13 02:01:47,362 - root - INFO - Original target: None
# 2024-11-13 02:01:47,363 - root - INFO - Initially extracted target: 19세 ~ 49세 울진 청년 누구나 모집인원 10명(선착순) 강의장소 울진청년일자리센터 1층(울진읍 읍내로 57 6) 기타사항 10명 선착순이나, 취소 등에 대비하여 예비 7명까지 추가 선발합니다. 사전 취소없이 당일 불참시 다음 강의 후순위로 배정됩니다. 원데이 클래스 054 789 6473
# 2024-11-13 02:01:47,365 - root - INFO - Final target value: 19세 ~ 49세 울진 청년 누구나 모집인원 10명(선착순) 강의장소 울진청년일자리센터 1층(울진읍 읍내로 57 6) 기타사항 10명 선착순이나, 취소 등에 대비하여 예비 7명까지 추가 선발합니다. 사전 취소없이 당일 불참시 다음 강의 후순위로 배정됩니다. 원데이 클래스 054 789 6473
# 2024-11-13 02:01:47,366 - root - INFO - Processing row idx: 4
# 2024-11-13 02:01:47,367 - root - INFO - Original target: None
# 2024-11-13 02:01:47,369 - root - INFO - Initially extracted target: 19세 ~ 49세 울진 청년 누구나 모집인원 10명(선착순) 강의장소 울진청년일자리센터 1층(울진읍 읍내로 57 6) 기타사항 10명 선착순이나, 취소 등에 대비하여 예비 7명까지 추가 선발합니다. 사전 취소없이 당일 불참시 다음 강의 후순위로 배정됩니다. 원데이 클래스 054 789 6473
# 2024-11-13 02:01:47,370 - root - INFO - Final target value: 19세 ~ 49세 울진 청년 누구나 모집인원 10명(선착순) 강의장소 울진청년일자리센터 1층(울진읍 읍내로 57 6) 기타사항 10명 선착순이나, 취소 등에 대비하여 예비 7명까지 추가 선발합니다. 사전 취소없이 당일 불참시 다음 강의 후순위로 배정됩니다. 원데이 클래스 054 789 6473
# 2024-11-13 02:01:47,371 - root - INFO - Processing row idx: 5
# 2024-11-13 02:01:47,372 - root - INFO - Original target: None
# 2024-11-13 02:01:47,373 - root - INFO - Initially extracted target: 출산예정일이 2024. 9. 1 이후인 관내 임산부 이용기간 출산예정일 이후 1개월까지 ((((( 2024.10.10일부터 운행중 ))))) 출산예정일이 24.9.1~24.11.30 임산부는 24.12.31.까지 한시적으로 이용기간 연장 신청구분 (온라인, 보건소방문신청) 온라인신청 청년e끌림 (회원가입 필요) 신청대상 1) 보건소 임산부 등록자 증 K맘택시 미신청자 2) 향후 보건소에 임산부 등록할 계획은 없으나, K맘택시를 이용하고자 하는 자 신청절차 로그인 > 검색창 ‘임산부’ 입력 > ‘구미시 임산부택시 신청’ 버튼 > 하단 '신청바로가기' 버튼 처리과정 청년e끌림신청 >신청승인(문자안내) >서버등록(문자안내 ) > 앱 설치 앱 설치 후 로그인시 바로 사용가능 ((((((((((( 가 입 하 기 금 지 )))))))))) 처리 기간은 10일 정도 소요됩니다. 보건소 방문신청 보건소 방문 임산부 등록 예정인자 ( 보건소 임산부등록 신청서류 신분증, 산모수첩, 임신확인서 등) 이용요금 5km까지 기본요금 1,100원, 5km 이후 km당 200원 추가 (최대 3,000원) 카드 혹은 현금 직접 결제 이용시간 07 ~ 22시 (주말, 공휴일 동일) 호출방법 경북임산부택시 ' k맘택시' 앱을 통해 호출 저출생 극복의 일환으로 임산부에 대하여 월10회 택시 배차 지원 대중교통과 택시화물팀 ☎054 480 2911
# 2024-11-13 02:01:47,374 - root - INFO - Final target value: 출산예정일이 2024. 9. 1 이후인 관내 임산부 이용기간 출산예정일 이후 1개월까지 ((((( 2024.10.10일부터 운행중 ))))) 출산예정일이 24.9.1~24.11.30 임산부는 24.12.31.까지 한시적으로 이용기간 연장 신청구분 (온라인, 보건소방문신청) 온라인신청 청년e끌림 (회원가입 필요) 신청대상 1) 보건소 임산부 등록자 증 K맘택시 미신청자 2) 향후 보건소에 임산부 등록할 계획은 없으나, K맘택시를 이용하고자 하는 자 신청절차 로그인 > 검색창 ‘임산부’ 입력 > ‘구미시 임산부택시 신청’ 버튼 > 하단 '신청바로가기' 버튼 처리과정 청년e끌림신청 >신청승인(문자안내) >서버등록(문자안내 ) > 앱 설치 앱 설치 후 로그인시 바로 사용가능 ((((((((((( 가 입 하 기 금 지 )))))))))) 처리 기간은 10일 정도 소요됩니다. 보건소 방문신청 보건소 방문 임산부 등록 예정인자 ( 보건소 임산부등록 신청서류 신분증, 산모수첩, 임신확인서 등) 이용요금 5km까지 기본요금 1,100원, 5km 이후 km당 200원 추가 (최대 3,000원) 카드 혹은 현금 직접 결제 이용시간 07 ~ 22시 (주말, 공휴일 동일) 호출방법 경북임산부택시 ' k맘택시' 앱을 통해 호출 저출생 극복의 일환으로 임산부에 대하여 월10회 택시 배차 지원 대중교통과 택시화물팀 ☎054 480 2911
# 2024-11-13 02:01:47,375 - root - INFO - Processing row idx: 6
# 2024-11-13 02:01:47,376 - root - INFO - Original target: None
# 2024-11-13 02:01:47,377 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,378 - root - INFO - Using original target:
# 2024-11-13 02:01:47,379 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,380 - root - INFO - Using cleaned subject as target: ① 면접수당 도내 중소·중견기업 면접 시 7만원 지원(1인 최대 5회) ② 취업성공수당 도내 중소·중견기업 생애 최초 취업 성공 시 50만원 지원(1인 1회) ③ 근속장려수당 도내 중소·중견기업 1년 이상 재직 시 120만원 지원(1인 1회)
# 2024-11-13 02:01:47,381 - root - INFO - Final target value: ① 면접수당 도내 중소·중견기업 면접 시 7만원 지원(1인 최대 5회) ② 취업성공수당 도내 중소·중견기업 생애 최초 취업 성공 시 50만원 지원(1인 1회) ③ 근속장려수당 도내 중소·중견기업 1년 이상 재직 시 120만원 지원(1인 1회)
# 2024-11-13 02:01:47,382 - root - INFO - Processing row idx: 7
# 2024-11-13 02:01:47,383 - root - INFO - Original target: None
# 2024-11-13 02:01:47,384 - root - INFO - Initially extracted target: 공고일 기준 구미시에 주민등록을 둔 부모와 별도 거주 중인 무주택 미혼 청년 세대주로 금융기관에서 전세보증금 대출 후 2022. 1. 1. ~ 신청일 사이에 이자를 6개월 이상 상환한 자 ‣ 청년기준 19 ~ 39세 만39세 기준이 되는 해(1984년)에 출생한 사람 포함 ‣ 연소득 4천5백만원 이하 ‣ 대출 시 용도가 전월세(임대)자금으로 명기된 경우에 한함 ‣ 국가 및 지자체 월세지원사업 수혜 중인자 제외 주택도시기금지원사업(버팀목전세자금, 중소기업취업청년전월세보증금대출 등), 공공임대주택, 정부 및 지자체 전세지원사업 수혜 중인자 신청가능 라. 대상주택 임차보증금 2억5천만원 이하, 전․월세 전환율 6.0%이하 구미시 소재의 주택 마. 지원내용 공고일기준 대출금액(잔액) 1% 지원 [최대 80만원, 생애 1회] 바. 지원 제외 대상 청년 본인 연소득 45백만원 초과 국민기초생활보장수급자 (생계, 의료, 주거, 교육급여 대상자) 주택 소유자(주거용 오피스텔포함), 분양권 또는 조합원 입주권이 있는 사람 국가 및 지자체 월세지원사업 수혜 중인자 ‣ 청년월세 한시 특별지원사업 수혜 중인자 ‣ 구미시 자체 월세지원사업 수혜 중인자 임대인이 신청인의 직계존비속인 경우 국가 및 지방자치단체 공무원(임기제), 공무직 직원 기타 사업 취지에 부합하지 않다고 판단되는 경우 2. 제출서류 [붙임1] 참고 (공고일 이후 발급분에 한함) ① 신청서 ② 개인정보 수집 및 활용 동의서 ③ 임대차계약서 ④ 금융거래확인서 ⑤ 지방세 세목별 미과세증명서(2023~2024년 기준 미과세증명) ⑥ 소득금액증명원(2023~2024년 기준) [재직근로자, 개인사업자, 프리랜서] ⑦ 사실증명(신고사실없음) [미취업자] ⑧ 통장사본 [신청인(대출자) 명의] ⑨ 주민등록등본 ⑩ 가족관계증명서(일반) [신청인 본인 기준] 담당자가 추가로 자료 보완을 요구할 수 있습니다. 3. 대상자 선정 및 결과통보 가. 선정방법 제출서류 검토 후 자격요건 부합 시 선정 ‣ 예산 초과시 배점표에 따라 총점 고득점자 순으로 우선 선정 ① 주택도시기금(버팀목 등), 공공임대주택, 정부 지자체 전세지원 미수혜자 ② 소득기준 낮은 순 ③ 임차보증금액 낮은 순 ④ 구미시 거주기간 동점자 처리기준 ⇒ 구미시 장기거주자 우선 나. 선정결과 선정결과 개별통보 (문자메시지) 4.
# 2024-11-13 02:01:47,385 - root - INFO - Final target value: 공고일 기준 구미시에 주민등록을 둔 부모와 별도 거주 중인 무주택 미혼 청년 세대주로 금융기관에서 전세보증금 대출 후 2022. 1. 1. ~ 신청일 사이에 이자를 6개월 이상 상환한 자 ‣ 청년기준 19 ~ 39세 만39세 기준이 되는 해(1984년)에 출생한 사람 포함 ‣ 연소득 4천5백만원 이하 ‣ 대출 시 용도가 전월세(임대)자금으로 명기된 경우에 한함 ‣ 국가 및 지자체 월세지원사업 수혜 중인자 제외 주택도시기금지원사업(버팀목전세자금, 중소기업취업청년전월세보증금대출 등), 공공임대주택, 정부 및 지자체 전세지원사업 수혜 중인자 신청가능 라. 대상주택 임차보증금 2억5천만원 이하, 전․월세 전환율 6.0%이하 구미시 소재의 주택 마. 지원내용 공고일기준 대출금액(잔액) 1% 지원 [최대 80만원, 생애 1회] 바. 지원 제외 대상 청년 본인 연소득 45백만원 초과 국민기초생활보장수급자 (생계, 의료, 주거, 교육급여 대상자) 주택 소유자(주거용 오피스텔포함), 분양권 또는 조합원 입주권이 있는 사람 국가 및 지자체 월세지원사업 수혜 중인자 ‣ 청년월세 한시 특별지원사업 수혜 중인자 ‣ 구미시 자체 월세지원사업 수혜 중인자 임대인이 신청인의 직계존비속인 경우 국가 및 지방자치단체 공무원(임기제), 공무직 직원 기타 사업 취지에 부합하지 않다고 판단되는 경우 2. 제출서류 [붙임1] 참고 (공고일 이후 발급분에 한함) ① 신청서 ② 개인정보 수집 및 활용 동의서 ③ 임대차계약서 ④ 금융거래확인서 ⑤ 지방세 세목별 미과세증명서(2023~2024년 기준 미과세증명) ⑥ 소득금액증명원(2023~2024년 기준) [재직근로자, 개인사업자, 프리랜서] ⑦ 사실증명(신고사실없음) [미취업자] ⑧ 통장사본 [신청인(대출자) 명의] ⑨ 주민등록등본 ⑩ 가족관계증명서(일반) [신청인 본인 기준] 담당자가 추가로 자료 보완을 요구할 수 있습니다. 3. 대상자 선정 및 결과통보 가. 선정방법 제출서류 검토 후 자격요건 부합 시 선정 ‣ 예산 초과시 배점표에 따라 총점 고득점자 순으로 우선 선정 ① 주택도시기금(버팀목 등), 공공임대주택, 정부 지자체 전세지원 미수혜자 ② 소득기준 낮은 순 ③ 임차보증금액 낮은 순 ④ 구미시 거주기간 동점자 처리기준 ⇒ 구미시 장기거주자 우선 나. 선정결과 선정결과 개별통보 (문자메시지) 4.
# 2024-11-13 02:01:47,386 - root - INFO - Processing row idx: 8
# 2024-11-13 02:01:47,388 - root - INFO - Original target: None
# 2024-11-13 02:01:47,389 - root - INFO - Initially extracted target: 자로 선정되었음을 통보받은 다음날부터 2025.12.31.까지 연속된 6개월 기간 내 고용한 대체인력의 인건비에 한해 지원 (근로조건) 주 5일 이하의 근무를 원칙으로 1일 근무시간이 8시간 미만(휴식시간 제외)일 경우는 시간급으로 계산. 근무형태는 전일제, 시간제 근무 모두 가능 ㅇ (인건비 지급요건) 근로계약서 및 통장입금 내역서를 확인하고 출산 소상공인(배우자)이 지급한 인건비 내에서 최대 2백만원 지원 경북 소상공인 출산장려 아이보듬 1800 8730
# 2024-11-13 02:01:47,390 - root - INFO - Final target value: 자로 선정되었음을 통보받은 다음날부터 2025.12.31.까지 연속된 6개월 기간 내 고용한 대체인력의 인건비에 한해 지원 (근로조건) 주 5일 이하의 근무를 원칙으로 1일 근무시간이 8시간 미만(휴식시간 제외)일 경우는 시간급으로 계산. 근무형태는 전일제, 시간제 근무 모두 가능 ㅇ (인건비 지급요건) 근로계약서 및 통장입금 내역서를 확인하고 출산 소상공인(배우자)이 지급한 인건비 내에서 최대 2백만원 지원 경북 소상공인 출산장려 아이보듬 1800 8730
# 2024-11-13 02:01:47,391 - root - INFO - Processing row idx: 9
# 2024-11-13 02:01:47,392 - root - INFO - Original target: None
# 2024-11-13 02:01:47,393 - root - INFO - Initially extracted target: 구미시에 주소를 둔 19~39세 이하 취업 지원자(미취업자) 라. 지원내용 면접정장 대여비 지원 구미소재기업 취업지원자 면접정장 2박 3일 대여, 1회 7만원, 연 3회 대여장소 레포르 테일러(구미 원남로 134, ☎453 1154) [ 대여일 기준 최소 5일전(주말제외, 주말신청 월요일 확인 가능) 신청해야 원하는 날짜 대여 가능] 취업사진 촬영비 지원 관내 사진관에서 취업준비용 증명사진 촬영시 촬영비 지급, 1회 최대 3만원, 연 1회 자격증 응시료 지원 2024년 자격증 시험 응시료 지원, 1인당 연 10만원 한도 내, 연 2회 마. 지급방법 청년 본인 계좌로 현금 지급 바.
# 2024-11-13 02:01:47,394 - root - INFO - Final target value: 구미시에 주소를 둔 19~39세 이하 취업 지원자(미취업자) 라. 지원내용 면접정장 대여비 지원 구미소재기업 취업지원자 면접정장 2박 3일 대여, 1회 7만원, 연 3회 대여장소 레포르 테일러(구미 원남로 134, ☎453 1154) [ 대여일 기준 최소 5일전(주말제외, 주말신청 월요일 확인 가능) 신청해야 원하는 날짜 대여 가능] 취업사진 촬영비 지원 관내 사진관에서 취업준비용 증명사진 촬영시 촬영비 지급, 1회 최대 3만원, 연 1회 자격증 응시료 지원 2024년 자격증 시험 응시료 지원, 1인당 연 10만원 한도 내, 연 2회 마. 지급방법 청년 본인 계좌로 현금 지급 바.
# 2024-11-13 02:01:47,395 - root - INFO - Processing row idx: 10
# 2024-11-13 02:01:47,397 - root - INFO - Original target: None
# 2024-11-13 02:01:47,398 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,399 - root - INFO - Using original target:
# 2024-11-13 02:01:47,400 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,400 - root - INFO - Using cleaned subject as target: 분할상환약정 체결을 위한 초입금(상환원리금의 5% 이내, 1회 1백만원 한도) 지원 (한국장학재단) 분할상환약정 체결을 통한 한국신용정보원 신용도판단정보 등록해제, 연체이자 징수 면제 및 체납자 법적조치 유보 등 신용회복 절차 지원
# 2024-11-13 02:01:47,401 - root - INFO - Final target value: 분할상환약정 체결을 위한 초입금(상환원리금의 5% 이내, 1회 1백만원 한도) 지원 (한국장학재단) 분할상환약정 체결을 통한 한국신용정보원 신용도판단정보 등록해제, 연체이자 징수 면제 및 체납자 법적조치 유보 등 신용회복 절차 지원
# 2024-11-13 02:01:47,403 - root - INFO - Processing row idx: 11
# 2024-11-13 02:01:47,404 - root - INFO - Original target: None
# 2024-11-13 02:01:47,404 - root - INFO - Initially extracted target: 신청일 기준 보증 효력이 유효한 전세보증금반환보증(HUG, HF, SGI)에 가입한 임차보증금 3억원 이하, 연소득 ①(청년)5천만원, ②(청년 외)6천만원, ③(신혼부부)7.5천만원 이하 무주택 임차인
# 2024-11-13 02:01:47,405 - root - INFO - Final target value: 신청일 기준 보증 효력이 유효한 전세보증금반환보증(HUG, HF, SGI)에 가입한 임차보증금 3억원 이하, 연소득 ①(청년)5천만원, ②(청년 외)6천만원, ③(신혼부부)7.5천만원 이하 무주택 임차인
# 2024-11-13 02:01:47,407 - root - INFO - Processing row idx: 12
# 2024-11-13 02:01:47,407 - root - INFO - Original target: None
# 2024-11-13 02:01:47,410 - root - INFO - Initially extracted target: 신청일 기준 보증 효력이 유효한 전세보증금반환보증(HUG, HF, SGI)에 가입한 임차보증금 3억원 이하, 연소득 ①(청년)5천만원, ②(청년 외)6천만원, ③(신혼부부)7.5천만원 이하 무주택 임차인
# 2024-11-13 02:01:47,410 - root - INFO - Final target value: 신청일 기준 보증 효력이 유효한 전세보증금반환보증(HUG, HF, SGI)에 가입한 임차보증금 3억원 이하, 연소득 ①(청년)5천만원, ②(청년 외)6천만원, ③(신혼부부)7.5천만원 이하 무주택 임차인
# 2024-11-13 02:01:47,411 - root - INFO - Processing row idx: 13
# 2024-11-13 02:01:47,412 - root - INFO - Original target: None
# 2024-11-13 02:01:47,413 - root - INFO - Initially extracted target: 19세 ~ 49세 울진 청년 누구나 모집인원 10명(선착순) 강의장소 울진청년일자리센터 1층(울진읍 읍내로 57 6) 기타사항 10명 선착순이나, 취소 등에 대비하여 예비 7명까지 추가 선발합니다. 사전 취소없이 당일 불참시 다음 강의 후순위로 배정됩니다. 원데이 클래스 054 789 6473
# 2024-11-13 02:01:47,414 - root - INFO - Final target value: 19세 ~ 49세 울진 청년 누구나 모집인원 10명(선착순) 강의장소 울진청년일자리센터 1층(울진읍 읍내로 57 6) 기타사항 10명 선착순이나, 취소 등에 대비하여 예비 7명까지 추가 선발합니다. 사전 취소없이 당일 불참시 다음 강의 후순위로 배정됩니다. 원데이 클래스 054 789 6473
# 2024-11-13 02:01:47,415 - root - INFO - Processing row idx: 14
# 2024-11-13 02:01:47,417 - root - INFO - Original target: None
# 2024-11-13 02:01:47,418 - root - INFO - Initially extracted target: 19세 ~ 49세 울진 청년 누구나 모집인원 10명(선착순) 강의장소 울진청년일자리센터 1층(울진읍 읍내로 57 6) 기타사항 10명 선착순이나, 취소 등에 대비하여 예비 7명까지 추가 선발합니다. 사전 취소없이 당일 불참시 다음 강의 후순위로 배정됩니다. 원데이 클래스 054 789 6473
# 2024-11-13 02:01:47,418 - root - INFO - Final target value: 19세 ~ 49세 울진 청년 누구나 모집인원 10명(선착순) 강의장소 울진청년일자리센터 1층(울진읍 읍내로 57 6) 기타사항 10명 선착순이나, 취소 등에 대비하여 예비 7명까지 추가 선발합니다. 사전 취소없이 당일 불참시 다음 강의 후순위로 배정됩니다. 원데이 클래스 054 789 6473
# 2024-11-13 02:01:47,419 - root - INFO - Processing row idx: 15
# 2024-11-13 02:01:47,420 - root - INFO - Original target: None
# 2024-11-13 02:01:47,421 - root - INFO - Initially extracted target: 출산예정일이 2024. 9. 1 이후인 관내 임산부 이용기간 출산예정일 이후 1개월까지 ((((( 2024.10.10일부터 운행중 ))))) 출산예정일이 24.9.1~24.11.30 임산부는 24.12.31.까지 한시적으로 이용기간 연장 신청구분 (온라인, 보건소방문신청) 온라인신청 청년e끌림 (회원가입 필요) 신청대상 1) 보건소 임산부 등록자 증 K맘택시 미신청자 2) 향후 보건소에 임산부 등록할 계획은 없으나, K맘택시를 이용하고자 하는 자 신청절차 로그인 > 검색창 ‘임산부’ 입력 > ‘구미시 임산부택시 신청’ 버튼 > 하단 '신청바로가기' 버튼 처리과정 청년e끌림신청 >신청승인(문자안내) >서버등록(문자안내 ) > 앱 설치 앱 설치 후 로그인시 바로 사용가능 ((((((((((( 가 입 하 기 금 지 )))))))))) 처리 기간은 10일 정도 소요됩니다. 보건소 방문신청 보건소 방문 임산부 등록 예정인자 ( 보건소 임산부등록 신청서류 신분증, 산모수첩, 임신확인서 등) 이용요금 5km까지 기본요금 1,100원, 5km 이후 km당 200원 추가 (최대 3,000원) 카드 혹은 현금 직접 결제 이용시간 07 ~ 22시 (주말, 공휴일 동일) 호출방법 경북임산부택시 ' k맘택시' 앱을 통해 호출 저출생 극복의 일환으로 임산부에 대하여 월10회 택시 배차 지원 대중교통과 택시화물팀 ☎054 480 2911
# 2024-11-13 02:01:47,422 - root - INFO - Final target value: 출산예정일이 2024. 9. 1 이후인 관내 임산부 이용기간 출산예정일 이후 1개월까지 ((((( 2024.10.10일부터 운행중 ))))) 출산예정일이 24.9.1~24.11.30 임산부는 24.12.31.까지 한시적으로 이용기간 연장 신청구분 (온라인, 보건소방문신청) 온라인신청 청년e끌림 (회원가입 필요) 신청대상 1) 보건소 임산부 등록자 증 K맘택시 미신청자 2) 향후 보건소에 임산부 등록할 계획은 없으나, K맘택시를 이용하고자 하는 자 신청절차 로그인 > 검색창 ‘임산부’ 입력 > ‘구미시 임산부택시 신청’ 버튼 > 하단 '신청바로가기' 버튼 처리과정 청년e끌림신청 >신청승인(문자안내) >서버등록(문자안내 ) > 앱 설치 앱 설치 후 로그인시 바로 사용가능 ((((((((((( 가 입 하 기 금 지 )))))))))) 처리 기간은 10일 정도 소요됩니다. 보건소 방문신청 보건소 방문 임산부 등록 예정인자 ( 보건소 임산부등록 신청서류 신분증, 산모수첩, 임신확인서 등) 이용요금 5km까지 기본요금 1,100원, 5km 이후 km당 200원 추가 (최대 3,000원) 카드 혹은 현금 직접 결제 이용시간 07 ~ 22시 (주말, 공휴일 동일) 호출방법 경북임산부택시 ' k맘택시' 앱을 통해 호출 저출생 극복의 일환으로 임산부에 대하여 월10회 택시 배차 지원 대중교통과 택시화물팀 ☎054 480 2911
# 2024-11-13 02:01:47,423 - root - INFO - Processing row idx: 16
# 2024-11-13 02:01:47,423 - root - INFO - Original target: None
# 2024-11-13 02:01:47,424 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,425 - root - INFO - Using original target:
# 2024-11-13 02:01:47,426 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,426 - root - INFO - Using cleaned subject as target: ① 면접수당 도내 중소·중견기업 면접 시 7만원 지원(1인 최대 5회) ② 취업성공수당 도내 중소·중견기업 생애 최초 취업 성공 시 50만원 지원(1인 1회) ③ 근속장려수당 도내 중소·중견기업 1년 이상 재직 시 120만원 지원(1인 1회)
# 2024-11-13 02:01:47,427 - root - INFO - Final target value: ① 면접수당 도내 중소·중견기업 면접 시 7만원 지원(1인 최대 5회) ② 취업성공수당 도내 중소·중견기업 생애 최초 취업 성공 시 50만원 지원(1인 1회) ③ 근속장려수당 도내 중소·중견기업 1년 이상 재직 시 120만원 지원(1인 1회)
# 2024-11-13 02:01:47,429 - root - INFO - Processing row idx: 17
# 2024-11-13 02:01:47,430 - root - INFO - Original target: None
# 2024-11-13 02:01:47,431 - root - INFO - Initially extracted target: 공고일 기준 구미시에 주민등록을 둔 부모와 별도 거주 중인 무주택 미혼 청년 세대주로 금융기관에서 전세보증금 대출 후 2022. 1. 1. ~ 신청일 사이에 이자를 6개월 이상 상환한 자 ‣ 청년기준 19 ~ 39세 만39세 기준이 되는 해(1984년)에 출생한 사람 포함 ‣ 연소득 4천5백만원 이하 ‣ 대출 시 용도가 전월세(임대)자금으로 명기된 경우에 한함 ‣ 국가 및 지자체 월세지원사업 수혜 중인자 제외 주택도시기금지원사업(버팀목전세자금, 중소기업취업청년전월세보증금대출 등), 공공임대주택, 정부 및 지자체 전세지원사업 수혜 중인자 신청가능 라. 대상주택 임차보증금 2억5천만원 이하, 전․월세 전환율 6.0%이하 구미시 소재의 주택 마. 지원내용 공고일기준 대출금액(잔액) 1% 지원 [최대 80만원, 생애 1회] 바. 지원 제외 대상 청년 본인 연소득 45백만원 초과 국민기초생활보장수급자 (생계, 의료, 주거, 교육급여 대상자) 주택 소유자(주거용 오피스텔포함), 분양권 또는 조합원 입주권이 있는 사람 국가 및 지자체 월세지원사업 수혜 중인자 ‣ 청년월세 한시 특별지원사업 수혜 중인자 ‣ 구미시 자체 월세지원사업 수혜 중인자 임대인이 신청인의 직계존비속인 경우 국가 및 지방자치단체 공무원(임기제), 공무직 직원 기타 사업 취지에 부합하지 않다고 판단되는 경우 2. 제출서류 [붙임1] 참고 (공고일 이후 발급분에 한함) ① 신청서 ② 개인정보 수집 및 활용 동의서 ③ 임대차계약서 ④ 금융거래확인서 ⑤ 지방세 세목별 미과세증명서(2023~2024년 기준 미과세증명) ⑥ 소득금액증명원(2023~2024년 기준) [재직근로자, 개인사업자, 프리랜서] ⑦ 사실증명(신고사실없음) [미취업자] ⑧ 통장사본 [신청인(대출자) 명의] ⑨ 주민등록등본 ⑩ 가족관계증명서(일반) [신청인 본인 기준] 담당자가 추가로 자료 보완을 요구할 수 있습니다. 3. 대상자 선정 및 결과통보 가. 선정방법 제출서류 검토 후 자격요건 부합 시 선정 ‣ 예산 초과시 배점표에 따라 총점 고득점자 순으로 우선 선정 ① 주택도시기금(버팀목 등), 공공임대주택, 정부 지자체 전세지원 미수혜자 ② 소득기준 낮은 순 ③ 임차보증금액 낮은 순 ④ 구미시 거주기간 동점자 처리기준 ⇒ 구미시 장기거주자 우선 나. 선정결과 선정결과 개별통보 (문자메시지) 4.
# 2024-11-13 02:01:47,432 - root - INFO - Final target value: 공고일 기준 구미시에 주민등록을 둔 부모와 별도 거주 중인 무주택 미혼 청년 세대주로 금융기관에서 전세보증금 대출 후 2022. 1. 1. ~ 신청일 사이에 이자를 6개월 이상 상환한 자 ‣ 청년기준 19 ~ 39세 만39세 기준이 되는 해(1984년)에 출생한 사람 포함 ‣ 연소득 4천5백만원 이하 ‣ 대출 시 용도가 전월세(임대)자금으로 명기된 경우에 한함 ‣ 국가 및 지자체 월세지원사업 수혜 중인자 제외 주택도시기금지원사업(버팀목전세자금, 중소기업취업청년전월세보증금대출 등), 공공임대주택, 정부 및 지자체 전세지원사업 수혜 중인자 신청가능 라. 대상주택 임차보증금 2억5천만원 이하, 전․월세 전환율 6.0%이하 구미시 소재의 주택 마. 지원내용 공고일기준 대출금액(잔액) 1% 지원 [최대 80만원, 생애 1회] 바. 지원 제외 대상 청년 본인 연소득 45백만원 초과 국민기초생활보장수급자 (생계, 의료, 주거, 교육급여 대상자) 주택 소유자(주거용 오피스텔포함), 분양권 또는 조합원 입주권이 있는 사람 국가 및 지자체 월세지원사업 수혜 중인자 ‣ 청년월세 한시 특별지원사업 수혜 중인자 ‣ 구미시 자체 월세지원사업 수혜 중인자 임대인이 신청인의 직계존비속인 경우 국가 및 지방자치단체 공무원(임기제), 공무직 직원 기타 사업 취지에 부합하지 않다고 판단되는 경우 2. 제출서류 [붙임1] 참고 (공고일 이후 발급분에 한함) ① 신청서 ② 개인정보 수집 및 활용 동의서 ③ 임대차계약서 ④ 금융거래확인서 ⑤ 지방세 세목별 미과세증명서(2023~2024년 기준 미과세증명) ⑥ 소득금액증명원(2023~2024년 기준) [재직근로자, 개인사업자, 프리랜서] ⑦ 사실증명(신고사실없음) [미취업자] ⑧ 통장사본 [신청인(대출자) 명의] ⑨ 주민등록등본 ⑩ 가족관계증명서(일반) [신청인 본인 기준] 담당자가 추가로 자료 보완을 요구할 수 있습니다. 3. 대상자 선정 및 결과통보 가. 선정방법 제출서류 검토 후 자격요건 부합 시 선정 ‣ 예산 초과시 배점표에 따라 총점 고득점자 순으로 우선 선정 ① 주택도시기금(버팀목 등), 공공임대주택, 정부 지자체 전세지원 미수혜자 ② 소득기준 낮은 순 ③ 임차보증금액 낮은 순 ④ 구미시 거주기간 동점자 처리기준 ⇒ 구미시 장기거주자 우선 나. 선정결과 선정결과 개별통보 (문자메시지) 4.
# 2024-11-13 02:01:47,434 - root - INFO - Processing row idx: 18
# 2024-11-13 02:01:47,435 - root - INFO - Original target: None
# 2024-11-13 02:01:47,437 - root - INFO - Initially extracted target: 자로 선정되었음을 통보받은 다음날부터 2025.12.31.까지 연속된 6개월 기간 내 고용한 대체인력의 인건비에 한해 지원 (근로조건) 주 5일 이하의 근무를 원칙으로 1일 근무시간이 8시간 미만(휴식시간 제외)일 경우는 시간급으로 계산. 근무형태는 전일제, 시간제 근무 모두 가능 ㅇ (인건비 지급요건) 근로계약서 및 통장입금 내역서를 확인하고 출산 소상공인(배우자)이 지급한 인건비 내에서 최대 2백만원 지원 경북 소상공인 출산장려 아이보듬 1800 8730
# 2024-11-13 02:01:47,439 - root - INFO - Final target value: 자로 선정되었음을 통보받은 다음날부터 2025.12.31.까지 연속된 6개월 기간 내 고용한 대체인력의 인건비에 한해 지원 (근로조건) 주 5일 이하의 근무를 원칙으로 1일 근무시간이 8시간 미만(휴식시간 제외)일 경우는 시간급으로 계산. 근무형태는 전일제, 시간제 근무 모두 가능 ㅇ (인건비 지급요건) 근로계약서 및 통장입금 내역서를 확인하고 출산 소상공인(배우자)이 지급한 인건비 내에서 최대 2백만원 지원 경북 소상공인 출산장려 아이보듬 1800 8730
# 2024-11-13 02:01:47,440 - root - INFO - Processing row idx: 19
# 2024-11-13 02:01:47,441 - root - INFO - Original target: None
# 2024-11-13 02:01:47,443 - root - INFO - Initially extracted target: 구미시에 주소를 둔 19~39세 이하 취업 지원자(미취업자) 라. 지원내용 면접정장 대여비 지원 구미소재기업 취업지원자 면접정장 2박 3일 대여, 1인당 연 210,000원 한도 대여장소 레포르 테일러(구미 원남로 134, ☎453 1154) [ 대여일 기준 최소 5일전(주말제외, 주말신청 월요일 확인 가능) 신청해야 원하는 날짜 대여 가능] 취업사진 촬영비 지원 관내 사진관에서 취업준비용 증명사진 촬영시 촬영비 지급, 1인당 연 70,000원 한도 자격증 응시료 지원 2024년 자격증 시험 응시료 지원, 1인당 연 10만원 한도 내 마. 지급방법 청년 본인 계좌로 현금 지급 바.
# 2024-11-13 02:01:47,445 - root - INFO - Final target value: 구미시에 주소를 둔 19~39세 이하 취업 지원자(미취업자) 라. 지원내용 면접정장 대여비 지원 구미소재기업 취업지원자 면접정장 2박 3일 대여, 1인당 연 210,000원 한도 대여장소 레포르 테일러(구미 원남로 134, ☎453 1154) [ 대여일 기준 최소 5일전(주말제외, 주말신청 월요일 확인 가능) 신청해야 원하는 날짜 대여 가능] 취업사진 촬영비 지원 관내 사진관에서 취업준비용 증명사진 촬영시 촬영비 지급, 1인당 연 70,000원 한도 자격증 응시료 지원 2024년 자격증 시험 응시료 지원, 1인당 연 10만원 한도 내 마. 지급방법 청년 본인 계좌로 현금 지급 바.
# 2024-11-13 02:01:47,448 - root - INFO - Processing row idx: 20
# 2024-11-13 02:01:47,452 - root - INFO - Original target: None
# 2024-11-13 02:01:47,453 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,455 - root - INFO - Using original target:
# 2024-11-13 02:01:47,456 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,459 - root - INFO - Using cleaned subject as target: 분할상환약정 체결을 위한 초입금(상환원리금의 5% 이내, 1회 1백만원 한도) 지원 (한국장학재단) 분할상환약정 체결을 통한 한국신용정보원 신용도판단정보 등록해제, 연체이자 징수 면제 및 체납자 법적조치 유보 등 신용회복 절차 지원
# 2024-11-13 02:01:47,461 - root - INFO - Final target value: 분할상환약정 체결을 위한 초입금(상환원리금의 5% 이내, 1회 1백만원 한도) 지원 (한국장학재단) 분할상환약정 체결을 통한 한국신용정보원 신용도판단정보 등록해제, 연체이자 징수 면제 및 체납자 법적조치 유보 등 신용회복 절차 지원
# 2024-11-13 02:01:47,463 - root - INFO - Processing row idx: 21
# 2024-11-13 02:01:47,464 - root - INFO - Original target: None
# 2024-11-13 02:01:47,466 - root - INFO - Initially extracted target: 신청일 기준 보증 효력이 유효한 전세보증금반환보증(HUG, HF, SGI)에 가입한 임차보증금 3억원 이하, 연소득 ①(청년)5천만원, ②(청년 외)6천만원, ③(신혼부부)7.5천만원 이하 무주택 임차인
# 2024-11-13 02:01:47,467 - root - INFO - Final target value: 신청일 기준 보증 효력이 유효한 전세보증금반환보증(HUG, HF, SGI)에 가입한 임차보증금 3억원 이하, 연소득 ①(청년)5천만원, ②(청년 외)6천만원, ③(신혼부부)7.5천만원 이하 무주택 임차인
# 2024-11-13 02:01:47,469 - root - INFO - Processing row idx: 22
# 2024-11-13 02:01:47,470 - root - INFO - Original target: None
# 2024-11-13 02:01:47,471 - root - INFO - Initially extracted target: 신청일 기준 보증 효력이 유효한 전세보증금반환보증(HUG, HF, SGI)에 가입한 임차보증금 3억원 이하, 연소득 ①(청년)5천만원, ②(청년 외)6천만원, ③(신혼부부)7.5천만원 이하 무주택 임차인
# 2024-11-13 02:01:47,473 - root - INFO - Final target value: 신청일 기준 보증 효력이 유효한 전세보증금반환보증(HUG, HF, SGI)에 가입한 임차보증금 3억원 이하, 연소득 ①(청년)5천만원, ②(청년 외)6천만원, ③(신혼부부)7.5천만원 이하 무주택 임차인
# 2024-11-13 02:01:47,475 - root - INFO - Processing row idx: 23
# 2024-11-13 02:01:47,476 - root - INFO - Original target: None
# 2024-11-13 02:01:47,478 - root - INFO - Initially extracted target: 기업 고용보험법 시행령 제12조 우선지원 대상기업 지원요건 우선지원 대상기업에 재직중인 임원, 부서장 등 중간관리자 또는 입사 1년 미만 신입사원 모집내용 ① 조직문화 교육 중간관리자급(계층별)이상 조직문화 혁신교육 상시 모집·운영(예산소진시 마감) ② 온보딩 교육 신입사원(1년 미만 / 39세 미만) 직장적응 교육 상시 모집·운영(예산소진시 마감)  조직문화 교육 프로그램_계층별 교육 대상 CEO, 인사관리자, 부서별 중간관리자 등 내용 중소기업 중간관리자 대상 조직문화 혁신에 필요한 교육 지원 일정 참여 기업별 일정·장소 추후 협의가능  신입사원 온보딩 교육 프로그램_신입교육 대상 입사 1년 미만 신입사원(39세 미만 청년) 내용 신입사원 대상 직장 적응을 위한 기본 역량향상 교육지원 일정 1참여 기업별 일정·장소 추후 협의가능 청년친화 조직문화 교육 및 신입직원 대상 직장 적응지원 교육 제공 김천시 청년센터 054 432 0073
# 2024-11-13 02:01:47,479 - root - INFO - Final target value: 기업 고용보험법 시행령 제12조 우선지원 대상기업 지원요건 우선지원 대상기업에 재직중인 임원, 부서장 등 중간관리자 또는 입사 1년 미만 신입사원 모집내용 ① 조직문화 교육 중간관리자급(계층별)이상 조직문화 혁신교육 상시 모집·운영(예산소진시 마감) ② 온보딩 교육 신입사원(1년 미만 / 39세 미만) 직장적응 교육 상시 모집·운영(예산소진시 마감)  조직문화 교육 프로그램_계층별 교육 대상 CEO, 인사관리자, 부서별 중간관리자 등 내용 중소기업 중간관리자 대상 조직문화 혁신에 필요한 교육 지원 일정 참여 기업별 일정·장소 추후 협의가능  신입사원 온보딩 교육 프로그램_신입교육 대상 입사 1년 미만 신입사원(39세 미만 청년) 내용 신입사원 대상 직장 적응을 위한 기본 역량향상 교육지원 일정 1참여 기업별 일정·장소 추후 협의가능 청년친화 조직문화 교육 및 신입직원 대상 직장 적응지원 교육 제공 김천시 청년센터 054 432 0073
# 2024-11-13 02:01:47,482 - root - INFO - Processing row idx: 24
# 2024-11-13 02:01:47,483 - root - INFO - Original target: None
# 2024-11-13 02:01:47,485 - root - INFO - Initially extracted target: 15 ~ 39세 청년 (김천시 미취업 청년) ㅇ 사업내용 청년의 구직단념예방을 위한 맞춤형 프로그램 제공 및 청년고용정책 연계 (인프라 제공) 청년 심리상담 등에 필요한 청년 친화적 공간 및 시설 등 인프라 제공 (프로그램 제공) ▴초기상담을 통해 개인 맞춤형 프로그램 설계·제안, ▴심리적 소진 청년에게 심리상담 지원(1인당 최대 10회) ▴니트화 예방 및 발굴을 주된 목적으로 하여 지역 청년의 일자리 상황 및 정주여건 등에 부합하는 다양한 프로그램 개설·제공 경력재설계 프로그램은 필수 제공, 이외 마음관리, 의사소통능력강화, 취업준비 등 (후속지원) 관련 청년고용정책을 촘촘히 연계 지원하고, 참여자 취업상태 등 관리 청년일경험지원, 청년도전지원사업, 국민취업지원제도, 국민내일배움카드(직업훈련) 등 ㅇ 지원내용 ❶ (초기상담 프로그램) 참여자와의 1 1 상담을 통해 참여욕구, 관심 직종 등 개별특성을 파악하고 개인 맞춤형 프로그램 설계‧제안 및 청년성장프로젝트 사업 이해 ❷ (맞춤형 프로그램) 20시간 이수 ㅇ
# 2024-11-13 02:01:47,486 - root - INFO - Final target value: 15 ~ 39세 청년 (김천시 미취업 청년) ㅇ 사업내용 청년의 구직단념예방을 위한 맞춤형 프로그램 제공 및 청년고용정책 연계 (인프라 제공) 청년 심리상담 등에 필요한 청년 친화적 공간 및 시설 등 인프라 제공 (프로그램 제공) ▴초기상담을 통해 개인 맞춤형 프로그램 설계·제안, ▴심리적 소진 청년에게 심리상담 지원(1인당 최대 10회) ▴니트화 예방 및 발굴을 주된 목적으로 하여 지역 청년의 일자리 상황 및 정주여건 등에 부합하는 다양한 프로그램 개설·제공 경력재설계 프로그램은 필수 제공, 이외 마음관리, 의사소통능력강화, 취업준비 등 (후속지원) 관련 청년고용정책을 촘촘히 연계 지원하고, 참여자 취업상태 등 관리 청년일경험지원, 청년도전지원사업, 국민취업지원제도, 국민내일배움카드(직업훈련) 등 ㅇ 지원내용 ❶ (초기상담 프로그램) 참여자와의 1 1 상담을 통해 참여욕구, 관심 직종 등 개별특성을 파악하고 개인 맞춤형 프로그램 설계‧제안 및 청년성장프로젝트 사업 이해 ❷ (맞춤형 프로그램) 20시간 이수 ㅇ
# 2024-11-13 02:01:47,487 - root - INFO - Processing row idx: 25
# 2024-11-13 02:01:47,489 - root - INFO - Original target: None
# 2024-11-13 02:01:47,490 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,490 - root - INFO - Using original target:
# 2024-11-13 02:01:47,491 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,492 - root - INFO - Using cleaned subject as target: 입주조건 입주기업은 청년센터를 본사로 하여야 하며 입주 계약일로부터 30일 이내에 본사 사업장 주소지를 청년센터 입주 사무실 로 변경 주소 경상북도 경산시 삼풍로 27 글로벌벤처동 3층 경북청년창업지원센터 월 1회 네트워킹 및 교육 등 행사 참여 必 청년센터 입주 사무실 주 2회 출근 必
# 2024-11-13 02:01:47,493 - root - INFO - Final target value: 입주조건 입주기업은 청년센터를 본사로 하여야 하며 입주 계약일로부터 30일 이내에 본사 사업장 주소지를 청년센터 입주 사무실 로 변경 주소 경상북도 경산시 삼풍로 27 글로벌벤처동 3층 경북청년창업지원센터 월 1회 네트워킹 및 교육 등 행사 참여 必 청년센터 입주 사무실 주 2회 출근 必
# 2024-11-13 02:01:47,494 - root - INFO - Processing row idx: 26
# 2024-11-13 02:01:47,495 - root - INFO - Original target: None
# 2024-11-13 02:01:47,496 - root - INFO - Initially extracted target: 청년친화 조직문화 교육 제공 미취업 청년 등의 구직단념을 예방하고, 입직초기 청년들의 직장적응 지원 [경상북도] 지방시대정책국 청년정책과(054 880 2757) , [김천] 경제관광국 일자리경제과 (054 420 6704) , [안동] 경제행정국 일자리경제과 (054 840 5310) , [구미] 미래도시기획실 인구청년과 (054 480 2522) , [영천] 경제환경산업국 일자리노사과 (054 330 6707) , [상주] 미래정책실 (054 537 7139) , [경산]경제환경국 일자리경제과 (053 810 5114) , [청도] 산업경제건설국 경제산림과(054 370 2235) , [예천] 기획예산실 (054 650 6807)
# 2024-11-13 02:01:47,497 - root - INFO - Final target value: 청년친화 조직문화 교육 제공 미취업 청년 등의 구직단념을 예방하고, 입직초기 청년들의 직장적응 지원 [경상북도] 지방시대정책국 청년정책과(054 880 2757) , [김천] 경제관광국 일자리경제과 (054 420 6704) , [안동] 경제행정국 일자리경제과 (054 840 5310) , [구미] 미래도시기획실 인구청년과 (054 480 2522) , [영천] 경제환경산업국 일자리노사과 (054 330 6707) , [상주] 미래정책실 (054 537 7139) , [경산]경제환경국 일자리경제과 (053 810 5114) , [청도] 산업경제건설국 경제산림과(054 370 2235) , [예천] 기획예산실 (054 650 6807)
# 2024-11-13 02:01:47,498 - root - INFO - Processing row idx: 27
# 2024-11-13 02:01:47,499 - root - INFO - Original target: None
# 2024-11-13 02:01:47,499 - root - INFO - Initially extracted target: 생물학관련 대학/ 대학원 재학생 및 야생생물 조사에 관심있는 일반시민 2024년도 교육생 모집공고 야생동물 실태조사 전문인력 양성교육 문의 054 850 6978
# 2024-11-13 02:01:47,500 - root - INFO - Final target value: 생물학관련 대학/ 대학원 재학생 및 야생생물 조사에 관심있는 일반시민 2024년도 교육생 모집공고 야생동물 실태조사 전문인력 양성교육 문의 054 850 6978
# 2024-11-13 02:01:47,502 - root - INFO - Processing row idx: 28
# 2024-11-13 02:01:47,503 - root - INFO - Original target: None
# 2024-11-13 02:01:47,503 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,504 - root - INFO - Using original target:
# 2024-11-13 02:01:47,505 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,506 - root - INFO - Using cleaned subject as target: 1. 1인 연간 100만원 행복카드(포인트) 지급 근속 유도를 위해 최초 선정시 50만원, 6개월 근속시 50만원 추가 지급 사용분야 건강관리, 여가활용, 자기계발 등의 분야에서 자유롭게 사용 가능 2. 복지항목 신청관리 및 승인, 복지대금 지급 3. 지원사업에 대한 만족도 조사 등을 통한 사후관리
# 2024-11-13 02:01:47,507 - root - INFO - Final target value: 1. 1인 연간 100만원 행복카드(포인트) 지급 근속 유도를 위해 최초 선정시 50만원, 6개월 근속시 50만원 추가 지급 사용분야 건강관리, 여가활용, 자기계발 등의 분야에서 자유롭게 사용 가능 2. 복지항목 신청관리 및 승인, 복지대금 지급 3. 지원사업에 대한 만족도 조사 등을 통한 사후관리
# 2024-11-13 02:01:47,507 - root - INFO - Processing row idx: 29
# 2024-11-13 02:01:47,508 - root - INFO - Original target: None
# 2024-11-13 02:01:47,509 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,510 - root - INFO - Using original target:
# 2024-11-13 02:01:47,511 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,511 - root - INFO - Using cleaned subject as target: 입주조건 입주기업은 청년센터를 본사로 하여야 하며 입주 계약일로부터 30일 이내에 본사 사업장 주소지를 청년센터 입주 사무실 로 변경 주소 경상북도 경산시 삼풍로 27 글로벌벤처동 3층 경북청년창업지원센터 월 1회 네트워킹 및 교육 등 행사 참여 必 청년센터 입주 사무실 주 2회 출근 必
# 2024-11-13 02:01:47,512 - root - INFO - Final target value: 입주조건 입주기업은 청년센터를 본사로 하여야 하며 입주 계약일로부터 30일 이내에 본사 사업장 주소지를 청년센터 입주 사무실 로 변경 주소 경상북도 경산시 삼풍로 27 글로벌벤처동 3층 경북청년창업지원센터 월 1회 네트워킹 및 교육 등 행사 참여 必 청년센터 입주 사무실 주 2회 출근 必
# 2024-11-13 02:01:47,513 - root - INFO - Processing row idx: 30
# 2024-11-13 02:01:47,514 - root - INFO - Original target: None
# 2024-11-13 02:01:47,515 - root - INFO - Initially extracted target: 영덕에 주소를 둔 만 19세 이상 만 45세 이하 미취업 청년 (1979. 1. 1. ~ 2005. 12. 31. 출생자) 지원내용 어학, 한국사, 국가공인자격증 시험 등 응시료 (국가공인 자격증 확인 – www.q net. r.kr) 지원금액 응시료 실비(10만원 한도) 1인당 연 2회 신청가능
# 2024-11-13 02:01:47,516 - root - INFO - Final target value: 영덕에 주소를 둔 만 19세 이상 만 45세 이하 미취업 청년 (1979. 1. 1. ~ 2005. 12. 31. 출생자) 지원내용 어학, 한국사, 국가공인자격증 시험 등 응시료 (국가공인 자격증 확인 – www.q net. r.kr) 지원금액 응시료 실비(10만원 한도) 1인당 연 2회 신청가능
# 2024-11-13 02:01:47,517 - root - INFO - Processing row idx: 31
# 2024-11-13 02:01:47,518 - root - INFO - Original target: None
# 2024-11-13 02:01:47,520 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,521 - root - INFO - Using original target:
# 2024-11-13 02:01:47,522 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,523 - root - INFO - Using cleaned subject as target: 대 상 부모님과 별도 거주하는 만19세 ~ 34세 이하 무주택자 청년(청약통장 가입자) 지원내용 월 임대료 최대 20만원씩 최대 12개월동안 지원 제출서류 월세신청서, 소득·재산신고서, 서약서, 임대차계약서, 월세이체증빙서류, 입금통장사본, 청약통장사본, 본인,부,모 기준 각각의 가족관계증명서(상세) 소득조건 원가구 기준 중위소득 100% 이하이면서 청년독립가구 기준 중위소득 60% 이하 재산조건 원가구 4억7천만원 이하 및 청년독립가구 1억22백만원 이하
# 2024-11-13 02:01:47,524 - root - INFO - Final target value: 대 상 부모님과 별도 거주하는 만19세 ~ 34세 이하 무주택자 청년(청약통장 가입자) 지원내용 월 임대료 최대 20만원씩 최대 12개월동안 지원 제출서류 월세신청서, 소득·재산신고서, 서약서, 임대차계약서, 월세이체증빙서류, 입금통장사본, 청약통장사본, 본인,부,모 기준 각각의 가족관계증명서(상세) 소득조건 원가구 기준 중위소득 100% 이하이면서 청년독립가구 기준 중위소득 60% 이하 재산조건 원가구 4억7천만원 이하 및 청년독립가구 1억22백만원 이하
# 2024-11-13 02:01:47,526 - root - INFO - Processing row idx: 32
# 2024-11-13 02:01:47,527 - root - INFO - Original target: None
# 2024-11-13 02:01:47,529 - root - INFO - Initially extracted target: 자 ⌜청년기본법⌟상 청년(만 19~34세 이하)으로 부모님과 별도 거주하는 무주택자 지원한도 실제 납부하는 임대료를 최대 240만원(월 최대 20만원)까지 최대 12개월(회) 동안 매월 분할 지원 지원자격 청년가구 소득 기준 중위소득 60% 이하, 원가구 소득 기준 중위소득 100% 이하 신청기간 '24.2.26. ~ '25.2..25. / 지급기간 '24.3.~ '26.12. 청년 주거비 지원 전담콜센터 1600 0777, 칠곡군청 일자리경제과 054 979 6547
# 2024-11-13 02:01:47,531 - root - INFO - Final target value: 자 ⌜청년기본법⌟상 청년(만 19~34세 이하)으로 부모님과 별도 거주하는 무주택자 지원한도 실제 납부하는 임대료를 최대 240만원(월 최대 20만원)까지 최대 12개월(회) 동안 매월 분할 지원 지원자격 청년가구 소득 기준 중위소득 60% 이하, 원가구 소득 기준 중위소득 100% 이하 신청기간 '24.2.26. ~ '25.2..25. / 지급기간 '24.3.~ '26.12. 청년 주거비 지원 전담콜센터 1600 0777, 칠곡군청 일자리경제과 054 979 6547
# 2024-11-13 02:01:47,533 - root - INFO - Processing row idx: 33
# 2024-11-13 02:01:47,536 - root - INFO - Original target: None
# 2024-11-13 02:01:47,538 - root - INFO - Initially extracted target: 청도군에 주소 또는 등록기준지(본적)을 둔 만 19세 이상 39세 이하의 예비 또는 창업 1년 이내 창업자 지원내용 ∙ 시설지원 창업공간, 회의실, 공용사무기기 등 ∙ 창업활동비(12백만원) 상품화제작비, 시장개척홍보비, 4대 보험료 등 ∙ 교육, 컨설팅(3백만원) 창업교육, 전문가 컨설팅, 1 1 개별 상담 지원분야 ∙ 기술창업, 지식창업, 6차산업창업, 일반창업 청년 창업 지원 054 370 2235
# 2024-11-13 02:01:47,540 - root - INFO - Final target value: 청도군에 주소 또는 등록기준지(본적)을 둔 만 19세 이상 39세 이하의 예비 또는 창업 1년 이내 창업자 지원내용 ∙ 시설지원 창업공간, 회의실, 공용사무기기 등 ∙ 창업활동비(12백만원) 상품화제작비, 시장개척홍보비, 4대 보험료 등 ∙ 교육, 컨설팅(3백만원) 창업교육, 전문가 컨설팅, 1 1 개별 상담 지원분야 ∙ 기술창업, 지식창업, 6차산업창업, 일반창업 청년 창업 지원 054 370 2235
# 2024-11-13 02:01:47,541 - root - INFO - Processing row idx: 34
# 2024-11-13 02:01:47,542 - root - INFO - Original target: None
# 2024-11-13 02:01:47,544 - root - INFO - Initially extracted target: 만 39세 이하 전국 청년(개인 또는 팀(최대 2명) 구성을 통한 신청 가능 지원내용 청년 1인당 사업화자금 및 활동비 20백만원 최대 2년간 지원 1년차 사업의 효과를 평가하여 2년차 지원 대상에서 제외할 수 있음 사업내용 지역자원과 특산품 등을 활용한 관광상품, 기념품 개발․판매 미술, 음악, 사진 등 청년문화예술 창작활동 지원 전시․체험공간, 청년카페, 음식점, 게스트하우스 등 운영 청년 창업 지원 054 370 2235
# 2024-11-13 02:01:47,545 - root - INFO - Final target value: 만 39세 이하 전국 청년(개인 또는 팀(최대 2명) 구성을 통한 신청 가능 지원내용 청년 1인당 사업화자금 및 활동비 20백만원 최대 2년간 지원 1년차 사업의 효과를 평가하여 2년차 지원 대상에서 제외할 수 있음 사업내용 지역자원과 특산품 등을 활용한 관광상품, 기념품 개발․판매 미술, 음악, 사진 등 청년문화예술 창작활동 지원 전시․체험공간, 청년카페, 음식점, 게스트하우스 등 운영 청년 창업 지원 054 370 2235
# 2024-11-13 02:01:47,547 - root - INFO - Processing row idx: 35
# 2024-11-13 02:01:47,552 - root - INFO - Original target: None
# 2024-11-13 02:01:47,553 - root - INFO - Initially extracted target: (기 업) 도내 소재 기업 중「중소기업기본법」상 중소기업 (인턴참여자) 미취업 청년, 결혼이민자, 새터민 등 취업애로계층 지원내용 총600만원(중소기업 300, 인턴사원 300) (중소기업) 채용 인턴 1명당 고용지원금 300만원 (인턴근로자) 정규직 전환 시 근속장려금 300만원 지급시기 및 방법 (중소기업) 인턴 2개월간 月 150만원씩2회(1·2월차) 분할 지급 (인턴근로자) 정규직 전환일로부터 3·10월차 각 150만원씩(2회) 분할 지급 기업 및 인턴 정규직 전환 지원 054 370 2235
# 2024-11-13 02:01:47,554 - root - INFO - Final target value: (기 업) 도내 소재 기업 중「중소기업기본법」상 중소기업 (인턴참여자) 미취업 청년, 결혼이민자, 새터민 등 취업애로계층 지원내용 총600만원(중소기업 300, 인턴사원 300) (중소기업) 채용 인턴 1명당 고용지원금 300만원 (인턴근로자) 정규직 전환 시 근속장려금 300만원 지급시기 및 방법 (중소기업) 인턴 2개월간 月 150만원씩2회(1·2월차) 분할 지급 (인턴근로자) 정규직 전환일로부터 3·10월차 각 150만원씩(2회) 분할 지급 기업 및 인턴 정규직 전환 지원 054 370 2235
# 2024-11-13 02:01:47,556 - root - INFO - Processing row idx: 36
# 2024-11-13 02:01:47,558 - root - INFO - Original target: None
# 2024-11-13 02:01:47,560 - root - INFO - Initially extracted target: 19세~34세 부모님과 별도 거주하는 무주택 청년(1989. 1. 1. ~ 2005. 12. 31. 출생) (주택) 월세 70만원 및 보증금 5천만원 이하 (소득) 청년가구 기준 중위소득 60% 이하 및 원가구(청년가구+부·모) 기준 중위소득 100% 이하 청년 중위소득 1인기준 60% 1,337,067원, 원가구(청년+부모) 중위소득 100% 3인기준 4,714,657원 (재산) 청년가구 1억 2천 2백만원 이하 및 원가구 4억 7천만원 이하
# 2024-11-13 02:01:47,561 - root - INFO - Final target value: 19세~34세 부모님과 별도 거주하는 무주택 청년(1989. 1. 1. ~ 2005. 12. 31. 출생) (주택) 월세 70만원 및 보증금 5천만원 이하 (소득) 청년가구 기준 중위소득 60% 이하 및 원가구(청년가구+부·모) 기준 중위소득 100% 이하 청년 중위소득 1인기준 60% 1,337,067원, 원가구(청년+부모) 중위소득 100% 3인기준 4,714,657원 (재산) 청년가구 1억 2천 2백만원 이하 및 원가구 4억 7천만원 이하
# 2024-11-13 02:01:47,563 - root - INFO - Processing row idx: 37
# 2024-11-13 02:01:47,564 - root - INFO - Original target: None
# 2024-11-13 02:01:47,565 - root - INFO - Initially extracted target: 군 내 19세 ~ 39세 미혼 청년근로자 사업내용 청년근로자 자산형성 지원(2년 만기예금, 1,060만원+이자) 청년적립금 360만원(매월 15만원, 총 24회 적립) 지자체 지원금 700만원(분기당 175만원. 총 4회 적립) 급여요건 2024년 기준 중위소득 150% 이하인 자 근무요건 청도군 내 중소, 중견기업에 주 30시간 이상 근무하고, 3개월 이상 재직하고 있는 자(동일 사업장에서 재직) 청년근로자 자산형성 지원 054 370 2235
# 2024-11-13 02:01:47,566 - root - INFO - Final target value: 군 내 19세 ~ 39세 미혼 청년근로자 사업내용 청년근로자 자산형성 지원(2년 만기예금, 1,060만원+이자) 청년적립금 360만원(매월 15만원, 총 24회 적립) 지자체 지원금 700만원(분기당 175만원. 총 4회 적립) 급여요건 2024년 기준 중위소득 150% 이하인 자 근무요건 청도군 내 중소, 중견기업에 주 30시간 이상 근무하고, 3개월 이상 재직하고 있는 자(동일 사업장에서 재직) 청년근로자 자산형성 지원 054 370 2235
# 2024-11-13 02:01:47,567 - root - INFO - Processing row idx: 38
# 2024-11-13 02:01:47,568 - root - INFO - Original target: None
# 2024-11-13 02:01:47,569 - root - INFO - Initially extracted target: 19세~34세 이하 청년으로, 부모와 별도 거주하는 무주택자 신청자격 청년가구 소득이 기준 중위소득 60% 이하이면서 원가구 소득이 기준 중위소득 100% 이하
# 2024-11-13 02:01:47,571 - root - INFO - Final target value: 19세~34세 이하 청년으로, 부모와 별도 거주하는 무주택자 신청자격 청년가구 소득이 기준 중위소득 60% 이하이면서 원가구 소득이 기준 중위소득 100% 이하
# 2024-11-13 02:01:47,573 - root - INFO - Processing row idx: 39
# 2024-11-13 02:01:47,574 - root - INFO - Original target: None
# 2024-11-13 02:01:47,575 - root - INFO - Initially extracted target: 6개월이상 취업 ,교육, 직업훈련 참여 이력이 없는 만 18 ~ 34세 청년 안동시 거주자는 39세까지 모집 지원내용 미취업 청년의 사회활동 참여 의욕 고취와 자신감 향상을 위한 프로그램, 참여수당 및 인센티브 지원 지원방법 워크넷 접속 후 '청년도전지원사업' 신청 미취업 청년의 사회활동 참여 의욕 고취와 자신감 향상을 위한 프로그램, 참여수당 및 인센티브 지원 전화 054 843 8532 이환매니저
# 2024-11-13 02:01:47,577 - root - INFO - Final target value: 6개월이상 취업 ,교육, 직업훈련 참여 이력이 없는 만 18 ~ 34세 청년 안동시 거주자는 39세까지 모집 지원내용 미취업 청년의 사회활동 참여 의욕 고취와 자신감 향상을 위한 프로그램, 참여수당 및 인센티브 지원 지원방법 워크넷 접속 후 '청년도전지원사업' 신청 미취업 청년의 사회활동 참여 의욕 고취와 자신감 향상을 위한 프로그램, 참여수당 및 인센티브 지원 전화 054 843 8532 이환매니저
# 2024-11-13 02:01:47,578 - root - INFO - Processing row idx: 40
# 2024-11-13 02:01:47,579 - root - INFO - Original target: None
# 2024-11-13 02:01:47,581 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,582 - root - INFO - Using original target:
# 2024-11-13 02:01:47,583 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,584 - root - INFO - Using cleaned subject as target: ㅇ 지원자격 구미시 거주 만 19~39세 1985.1.1.~2005.12.31. 미취업 청년 및 구미시 소재 대학교 재학생(휴학생/대학원생 포함)중 경상북도내 주민등록 ㅇ 지원내용 ① 꿈이음카페 음료 모바일 포인트 지원 개인당 7만원 상당 포인트 지급(모바일 어플리케이션 이용) (1차) 4만 포인트 선지급, (2차) 4만포인트 80%이상 소진 및 프로그램 2회이상 참여자에게 3만포인트 후지급 ㅇ 모집기간 2023. 4. 8.(월) ~ 모집완료시까지 ㅇ 접수방법 붙임QR코드 스캔 또는 이메일 발송 (k_dscj b@daum.net) 온라인 신청 시 반드시 유선으로 접수 여부 확인 필요 (054 441 1313)
# 2024-11-13 02:01:47,585 - root - INFO - Final target value: ㅇ 지원자격 구미시 거주 만 19~39세 1985.1.1.~2005.12.31. 미취업 청년 및 구미시 소재 대학교 재학생(휴학생/대학원생 포함)중 경상북도내 주민등록 ㅇ 지원내용 ① 꿈이음카페 음료 모바일 포인트 지원 개인당 7만원 상당 포인트 지급(모바일 어플리케이션 이용) (1차) 4만 포인트 선지급, (2차) 4만포인트 80%이상 소진 및 프로그램 2회이상 참여자에게 3만포인트 후지급 ㅇ 모집기간 2023. 4. 8.(월) ~ 모집완료시까지 ㅇ 접수방법 붙임QR코드 스캔 또는 이메일 발송 (k_dscj b@daum.net) 온라인 신청 시 반드시 유선으로 접수 여부 확인 필요 (054 441 1313)
# 2024-11-13 02:01:47,586 - root - INFO - Processing row idx: 41
# 2024-11-13 02:01:47,587 - root - INFO - Original target: None
# 2024-11-13 02:01:47,588 - root - INFO - Initially extracted target: 제외 청춘카페 주관 취․창업 관련 기획프로그램 지원 청춘카페를 활용한 네트워킹 및 멘토링 등 다양한 활동 공간 제공 참여 활동 종료 후 활동보고서(참가후기) 제출 2024 꿈이음 청춘카페 지원사업 참여청년 모집 문의처 경북테크노파크 기업지원단 혁신기업지원센터 053 819 3073
# 2024-11-13 02:01:47,589 - root - INFO - Final target value: 제외 청춘카페 주관 취․창업 관련 기획프로그램 지원 청춘카페를 활용한 네트워킹 및 멘토링 등 다양한 활동 공간 제공 참여 활동 종료 후 활동보고서(참가후기) 제출 2024 꿈이음 청춘카페 지원사업 참여청년 모집 문의처 경북테크노파크 기업지원단 혁신기업지원센터 053 819 3073
# 2024-11-13 02:01:47,590 - root - INFO - Processing row idx: 42
# 2024-11-13 02:01:47,591 - root - INFO - Original target: None
# 2024-11-13 02:01:47,592 - root - INFO - Initially extracted target: 신규 청년고용실적이 우수한 구미 관내중소기업 (4개사 정도) ∙ 전년도 12월말 대비 고용(인원) 증가가 있으며, ’24년도 신규청년 고용 실적이 우수한 관내 중소기업 사업내용 근로자 복지시설 개보수 또는 물품 구입 비용 지원 지원내용 기업당 10백만원 ~ 40백만원 ∙ (지원금액) 신규청년채용인원에 따른 차등 지원 운영방법 (재)경상북도경제진흥원 위탁운영 지원금액 신규청년채용인원에 따른 차등지원 (10백만원 ~ 40백만원) ∙ 3인 이상 ~ 4인 이하 10백만원(단, 50인 이하 소규모 기업) ∙ 5인 이상 ~ 6인 이하 20백만원 ∙ 7인 이상 ~ 8인 이하 30백만원 ∙ 9인 이상 40백만원 지원분야 근로자 복지시설 개보수 및 물품 구입 지원 ∙ 시설 개보수 지원 휴게실, 기숙사, 체력단련실, 목욕시설, 화장실, 구내식당 등 노후화로 인한 근로환경개선 시설 설치 및 개보수 비용 지원 ∙ 물품 구입 지원 냉난방기, 운동기구, 냉장고, 세탁기, 공기정화기 등 기숙사·휴게실·식당 등 근로자 복지시설 내 근로환경개선 물품 지원 단, 물품 구입만 지원하는 것은 불가하며 지원금액의 50% 초과 불가 임대사업장은 물품 구입만 지원가능 자가 사업장은 시설 개보수지원 + 물품 구입 지원 신규 청년고용실적이 우수한 관내중소기업 에 근로자 복지시설 개보수 또는 물품 구입비용 지원 (1천만원 ~ 4천만원) 경상북도경제진흥원 일자리창출팀 054 470 8592
# 2024-11-13 02:01:47,593 - root - INFO - Final target value: 신규 청년고용실적이 우수한 구미 관내중소기업 (4개사 정도) ∙ 전년도 12월말 대비 고용(인원) 증가가 있으며, ’24년도 신규청년 고용 실적이 우수한 관내 중소기업 사업내용 근로자 복지시설 개보수 또는 물품 구입 비용 지원 지원내용 기업당 10백만원 ~ 40백만원 ∙ (지원금액) 신규청년채용인원에 따른 차등 지원 운영방법 (재)경상북도경제진흥원 위탁운영 지원금액 신규청년채용인원에 따른 차등지원 (10백만원 ~ 40백만원) ∙ 3인 이상 ~ 4인 이하 10백만원(단, 50인 이하 소규모 기업) ∙ 5인 이상 ~ 6인 이하 20백만원 ∙ 7인 이상 ~ 8인 이하 30백만원 ∙ 9인 이상 40백만원 지원분야 근로자 복지시설 개보수 및 물품 구입 지원 ∙ 시설 개보수 지원 휴게실, 기숙사, 체력단련실, 목욕시설, 화장실, 구내식당 등 노후화로 인한 근로환경개선 시설 설치 및 개보수 비용 지원 ∙ 물품 구입 지원 냉난방기, 운동기구, 냉장고, 세탁기, 공기정화기 등 기숙사·휴게실·식당 등 근로자 복지시설 내 근로환경개선 물품 지원 단, 물품 구입만 지원하는 것은 불가하며 지원금액의 50% 초과 불가 임대사업장은 물품 구입만 지원가능 자가 사업장은 시설 개보수지원 + 물품 구입 지원 신규 청년고용실적이 우수한 관내중소기업 에 근로자 복지시설 개보수 또는 물품 구입비용 지원 (1천만원 ~ 4천만원) 경상북도경제진흥원 일자리창출팀 054 470 8592
# 2024-11-13 02:01:47,594 - root - INFO - Processing row idx: 43
# 2024-11-13 02:01:47,595 - root - INFO - Original target: None
# 2024-11-13 02:01:47,596 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,596 - root - INFO - Using original target:
# 2024-11-13 02:01:47,597 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,598 - root - INFO - Using cleaned subject as target: (청년설발 및 지원) 취창업 준비 등 19세~39세 주소지가 경북인 청년 선발, 카페음료모바일(7만포인트)지급, 취창업 프로그램 지원 (꿈이음카페모집) 유동인구가 많고 접근성이 좋은 대학가 및 교통거점 등 선정 취창업 관련 프로그램 발굴 및 운영 (지역기업 모집) 청년일자리 창출 우수기업, 지역특화 청년창업기업 등 선정
# 2024-11-13 02:01:47,598 - root - INFO - Final target value: (청년설발 및 지원) 취창업 준비 등 19세~39세 주소지가 경북인 청년 선발, 카페음료모바일(7만포인트)지급, 취창업 프로그램 지원 (꿈이음카페모집) 유동인구가 많고 접근성이 좋은 대학가 및 교통거점 등 선정 취창업 관련 프로그램 발굴 및 운영 (지역기업 모집) 청년일자리 창출 우수기업, 지역특화 청년창업기업 등 선정
# 2024-11-13 02:01:47,600 - root - INFO - Processing row idx: 44
# 2024-11-13 02:01:47,600 - root - INFO - Original target: None
# 2024-11-13 02:01:47,601 - root - INFO - Initially extracted target: 상주시 청년과 지역주민으로 이루어진 팀 지원내용 200만원/팀, 프로젝트 추진비 지원 청년과 지역주민이 협업하여 부가가치 향상시키는 프로젝트 추진비 지원 054 537 7140
# 2024-11-13 02:01:47,602 - root - INFO - Final target value: 상주시 청년과 지역주민으로 이루어진 팀 지원내용 200만원/팀, 프로젝트 추진비 지원 청년과 지역주민이 협업하여 부가가치 향상시키는 프로젝트 추진비 지원 054 537 7140
# 2024-11-13 02:01:47,603 - root - INFO - Processing row idx: 45
# 2024-11-13 02:01:47,604 - root - INFO - Original target: None
# 2024-11-13 02:01:47,605 - root - INFO - Initially extracted target: 청년으로 구성된 5인 이상의 동아리 지원내용 200만원/팀, 동아리 모임 활동비 지원 청년 동아리 모임 활동비 지원 054 537 7140
# 2024-11-13 02:01:47,606 - root - INFO - Final target value: 청년으로 구성된 5인 이상의 동아리 지원내용 200만원/팀, 동아리 모임 활동비 지원 청년 동아리 모임 활동비 지원 054 537 7140
# 2024-11-13 02:01:47,607 - root - INFO - Processing row idx: 46
# 2024-11-13 02:01:47,607 - root - INFO - Original target: None
# 2024-11-13 02:01:47,608 - root - INFO - Initially extracted target: 자 자격증 응시료 지원 054 537 7140
# 2024-11-13 02:01:47,609 - root - INFO - Final target value: 자 자격증 응시료 지원 054 537 7140
# 2024-11-13 02:01:47,609 - root - INFO - Processing row idx: 47
# 2024-11-13 02:01:47,610 - root - INFO - Original target: None
# 2024-11-13 02:01:47,611 - root - INFO - Initially extracted target: 상주시 청년 창업 지원사업 참여자 지원내용 최대 월 30만원(임차료의 80%), 10개월간 지원 청년 창업 지원사업 등에 참여한 청년에게 주거 임차비 지원 054 537 7140
# 2024-11-13 02:01:47,612 - root - INFO - Final target value: 상주시 청년 창업 지원사업 참여자 지원내용 최대 월 30만원(임차료의 80%), 10개월간 지원 청년 창업 지원사업 등에 참여한 청년에게 주거 임차비 지원 054 537 7140
# 2024-11-13 02:01:47,613 - root - INFO - Processing row idx: 48
# 2024-11-13 02:01:47,614 - root - INFO - Original target: None
# 2024-11-13 02:01:47,615 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,615 - root - INFO - Using original target:
# 2024-11-13 02:01:47,616 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,616 - root - INFO - Using cleaned subject as target: 결혼이민여성 이중언어강사 양성 및 파견
# 2024-11-13 02:01:47,617 - root - INFO - Final target value: 결혼이민여성 이중언어강사 양성 및 파견
# 2024-11-13 02:01:47,618 - root - INFO - Processing row idx: 49
# 2024-11-13 02:01:47,619 - root - INFO - Original target: None
# 2024-11-13 02:01:47,620 - root - INFO - Initially extracted target: 으로 청년창업LAB교육 구미전자정보기술원 054 479 2073
# 2024-11-13 02:01:47,621 - root - INFO - Final target value: 으로 청년창업LAB교육 구미전자정보기술원 054 479 2073
# 2024-11-13 02:01:47,622 - root - INFO - Processing row idx: 50
# 2024-11-13 02:01:47,623 - root - INFO - Original target: None
# 2024-11-13 02:01:47,624 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,624 - root - INFO - Using original target:
# 2024-11-13 02:01:47,625 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,626 - root - INFO - Using cleaned subject as target: 입주조건 입주기업은 청년센터를 본사로 하여야 하며 입주 계약일로부터 30일 이내에 본사 사업장 주소지를 청년센터 입주 사무실 로 변경 주소 경상북도 경산시 삼풍로 27 글로벌벤처동 3층 경북청년창업지원센터 월 1회 네트워킹 및 교육 등 행사 참여 必 청년센터 입주 사무실 주 2회 출근 必
# 2024-11-13 02:01:47,627 - root - INFO - Final target value: 입주조건 입주기업은 청년센터를 본사로 하여야 하며 입주 계약일로부터 30일 이내에 본사 사업장 주소지를 청년센터 입주 사무실 로 변경 주소 경상북도 경산시 삼풍로 27 글로벌벤처동 3층 경북청년창업지원센터 월 1회 네트워킹 및 교육 등 행사 참여 必 청년센터 입주 사무실 주 2회 출근 必
# 2024-11-13 02:01:47,629 - root - INFO - Processing row idx: 51
# 2024-11-13 02:01:47,630 - root - INFO - Original target: None
# 2024-11-13 02:01:47,630 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,631 - root - INFO - Using original target:
# 2024-11-13 02:01:47,631 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,632 - root - INFO - Using cleaned subject as target: 내일은 디자인 컨설턴트 지원사업 참여 컨설턴트 모집 운영 도내 중소기업 디자인 제작 지원(지적재산권 등록 포함) 디자인 컨설턴트 및 수혜기업 간 네트워킹 프로그램 개최 등
# 2024-11-13 02:01:47,633 - root - INFO - Final target value: 내일은 디자인 컨설턴트 지원사업 참여 컨설턴트 모집 운영 도내 중소기업 디자인 제작 지원(지적재산권 등록 포함) 디자인 컨설턴트 및 수혜기업 간 네트워킹 프로그램 개최 등
# 2024-11-13 02:01:47,636 - root - INFO - Processing row idx: 52
# 2024-11-13 02:01:47,637 - root - INFO - Original target: None
# 2024-11-13 02:01:47,639 - root - INFO - Initially extracted target: 구미시 소재 중소기업 및 관내 미취업 청년(19~39세) 사업내용 1인당 600만원(중소기업 300, 인턴사원 300) (중 소 기 업) 채용 인턴 1명당 고용지원금 300만원 (인턴근로자) 정규직 전환 시 근속장려금 300만원 운영방법 보조사업자 위탁 운영 구미중소기업협의회, 여성인력개발센터, 경상북도경영자총협회(신규) 기 업 구미시 소재 기업 중「중소기업기본법」상 중소기업 (자격요건) 해당업종별 “평균매출액 등”이 ‘중소기업 규모기준’에 맞고 자산총액이 5천억원 미만인 기업 사업장 피고용자수가 300인 미만인 기업 인턴 약정체결 시 당사자 간 정한 약정 임금 수준이 ’24년 최저임금을 반영한 임금 이상인 경우만 참여 가능 ’24년 최저임금 2,060,740원 반영(최저시급 9,860원 / ‘23.8.4字 고용노동부 고시) 급여 상한선 기본급여 기준 300만원 (지원제외) 고용보험료 체납 사업장 인턴고용지원약정 체결일 이전 3개월 이내에 고용조정을 실시한 사업장 3개월 미만의 계절적·일시적 인력수요업체 기타 직계존․비속 및 배우자 등 친족이 경영하는 사업장 및 산업현장이 없는 기업체로 인턴연수에 부적합하다고 판단하는 사업장 임금으로 보기 어려운 부정기적 성과급만을 지급하는 직종 (예 다단계판매업체 판매원, 학습지회사 학습지 교사, 보험회사보험설계사 등) 정규직 전환에 따른 근로계약체결 시 임금후퇴가 발생한 기업 인턴참여자 관내 19~39세 미취업 청년 (자격요건) 주민등록 상 주소지가 구미시인 19~39세 미취업 청년 미취업자 대상(2024. 1. 1. 이후 취업자 ) ‘24년도 공고일 이전 취업자 사업참여 가능(사업 활성화를 위해 인턴참여자 자격 요건 완화) 사업내용 1인당 600만원 (중소기업 300, 인턴사원 300) 구미중소기업협의회(☎ 054 475 9280 // FAX. 054 475 9270 // E mail. kkd@gumisb. r.kr ) 구미여성인력개발센터(☎054 456 9497) 경북경영자총협회(☎054 461 5523)
# 2024-11-13 02:01:47,639 - root - INFO - Final target value: 구미시 소재 중소기업 및 관내 미취업 청년(19~39세) 사업내용 1인당 600만원(중소기업 300, 인턴사원 300) (중 소 기 업) 채용 인턴 1명당 고용지원금 300만원 (인턴근로자) 정규직 전환 시 근속장려금 300만원 운영방법 보조사업자 위탁 운영 구미중소기업협의회, 여성인력개발센터, 경상북도경영자총협회(신규) 기 업 구미시 소재 기업 중「중소기업기본법」상 중소기업 (자격요건) 해당업종별 “평균매출액 등”이 ‘중소기업 규모기준’에 맞고 자산총액이 5천억원 미만인 기업 사업장 피고용자수가 300인 미만인 기업 인턴 약정체결 시 당사자 간 정한 약정 임금 수준이 ’24년 최저임금을 반영한 임금 이상인 경우만 참여 가능 ’24년 최저임금 2,060,740원 반영(최저시급 9,860원 / ‘23.8.4字 고용노동부 고시) 급여 상한선 기본급여 기준 300만원 (지원제외) 고용보험료 체납 사업장 인턴고용지원약정 체결일 이전 3개월 이내에 고용조정을 실시한 사업장 3개월 미만의 계절적·일시적 인력수요업체 기타 직계존․비속 및 배우자 등 친족이 경영하는 사업장 및 산업현장이 없는 기업체로 인턴연수에 부적합하다고 판단하는 사업장 임금으로 보기 어려운 부정기적 성과급만을 지급하는 직종 (예 다단계판매업체 판매원, 학습지회사 학습지 교사, 보험회사보험설계사 등) 정규직 전환에 따른 근로계약체결 시 임금후퇴가 발생한 기업 인턴참여자 관내 19~39세 미취업 청년 (자격요건) 주민등록 상 주소지가 구미시인 19~39세 미취업 청년 미취업자 대상(2024. 1. 1. 이후 취업자 ) ‘24년도 공고일 이전 취업자 사업참여 가능(사업 활성화를 위해 인턴참여자 자격 요건 완화) 사업내용 1인당 600만원 (중소기업 300, 인턴사원 300) 구미중소기업협의회(☎ 054 475 9280 // FAX. 054 475 9270 // E mail. kkd@gumisb. r.kr ) 구미여성인력개발센터(☎054 456 9497) 경북경영자총협회(☎054 461 5523)
# 2024-11-13 02:01:47,641 - root - INFO - Processing row idx: 53
# 2024-11-13 02:01:47,642 - root - INFO - Original target: None
# 2024-11-13 02:01:47,643 - root - INFO - Initially extracted target: 경북지역 조리관련 전공자 및 어촌에 관심있는 청년 사업내용 레시피 조리교육, 바다요리 콘테스트, 지역축제 참가 등 선정기준 국내 거주 청년(만19~39세)대상 조리관련 전공자 및 경력자 우대 2. 청년과 함께하는 어촌문화 입히기(스토리텔링부문) 추진방향 센터 직접수행 사업기간 2024. 3월 ~ 10월 사업예산 70,000,000원 사업대상 대학생 및 홍보 활동 경험이 있는 온라인 에디터 등 사업내용 스토리텔링, 아카이브 구축, 서포터즈 운영 및 어촌 경관개선 선정기준 국내 거주 청년(만19~39세)대상 작가관련 전공자 및 경력주 우대 청년들이 학기 중 반은 학교에서 배우고, 반은 어촌에서 활동한다는 의미로 어촌의 요리, 문화 등을 도출하여 어촌을 홍보하기 위한 현장실습형 프로그램 경북어촌특화지원센터 담당 연구원 전화 054 780 3476 이메일 ejejk@mire.re.kr
# 2024-11-13 02:01:47,643 - root - INFO - Final target value: 경북지역 조리관련 전공자 및 어촌에 관심있는 청년 사업내용 레시피 조리교육, 바다요리 콘테스트, 지역축제 참가 등 선정기준 국내 거주 청년(만19~39세)대상 조리관련 전공자 및 경력자 우대 2. 청년과 함께하는 어촌문화 입히기(스토리텔링부문) 추진방향 센터 직접수행 사업기간 2024. 3월 ~ 10월 사업예산 70,000,000원 사업대상 대학생 및 홍보 활동 경험이 있는 온라인 에디터 등 사업내용 스토리텔링, 아카이브 구축, 서포터즈 운영 및 어촌 경관개선 선정기준 국내 거주 청년(만19~39세)대상 작가관련 전공자 및 경력주 우대 청년들이 학기 중 반은 학교에서 배우고, 반은 어촌에서 활동한다는 의미로 어촌의 요리, 문화 등을 도출하여 어촌을 홍보하기 위한 현장실습형 프로그램 경북어촌특화지원센터 담당 연구원 전화 054 780 3476 이메일 ejejk@mire.re.kr
# 2024-11-13 02:01:47,645 - root - INFO - Processing row idx: 54
# 2024-11-13 02:01:47,646 - root - INFO - Original target: None
# 2024-11-13 02:01:47,647 - root - INFO - Initially extracted target: 경북도민(최소3인 이상의 공동체) 문 의 처 054 996 9953, kbsi1130@naver.c m 2024년 주민참여 리빙랩 운영 공모전 (사)경북시민재단 054 996 9953
# 2024-11-13 02:01:47,648 - root - INFO - Final target value: 경북도민(최소3인 이상의 공동체) 문 의 처 054 996 9953, kbsi1130@naver.c m 2024년 주민참여 리빙랩 운영 공모전 (사)경북시민재단 054 996 9953
# 2024-11-13 02:01:47,649 - root - INFO - Processing row idx: 55
# 2024-11-13 02:01:47,650 - root - INFO - Original target: None
# 2024-11-13 02:01:47,651 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,652 - root - INFO - Using original target:
# 2024-11-13 02:01:47,653 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,655 - root - INFO - Using cleaned subject as target: RISE 체계 내에서‘인재양성 취·창업 지역정주’로 이어지는 선순환 구축을 위한 글로컬대학 집중 투자 ‧ 지원 추진 산업계 우수인력을 글로컬대학 교원으로 파견 ‧ 활용, 산업계 맞춤형 교육과정 공동개발 및 산학협력 공동연구 지원
# 2024-11-13 02:01:47,656 - root - INFO - Final target value: RISE 체계 내에서‘인재양성 취·창업 지역정주’로 이어지는 선순환 구축을 위한 글로컬대학 집중 투자 ‧ 지원 추진 산업계 우수인력을 글로컬대학 교원으로 파견 ‧ 활용, 산업계 맞춤형 교육과정 공동개발 및 산학협력 공동연구 지원
# 2024-11-13 02:01:47,657 - root - INFO - Processing row idx: 56
# 2024-11-13 02:01:47,659 - root - INFO - Original target: None
# 2024-11-13 02:01:47,660 - root - INFO - Initially extracted target: 18세 이상 45세 이하 취업을 준비 중(미취업)인 청년 공인어학 시험의 경우 요건 충족 시 시험응시료(최대 5회) 및 증명서 발급 비용만 지원 가능 자격증 취득 또는 어학 시험 지원요건 충족 시 소요경비 최대 1백만원 지원 고령군청 인구정책과 청년정책팀(054 950 6589)
# 2024-11-13 02:01:47,661 - root - INFO - Final target value: 18세 이상 45세 이하 취업을 준비 중(미취업)인 청년 공인어학 시험의 경우 요건 충족 시 시험응시료(최대 5회) 및 증명서 발급 비용만 지원 가능 자격증 취득 또는 어학 시험 지원요건 충족 시 소요경비 최대 1백만원 지원 고령군청 인구정책과 청년정책팀(054 950 6589)
# 2024-11-13 02:01:47,663 - root - INFO - Processing row idx: 57
# 2024-11-13 02:01:47,664 - root - INFO - Original target: None
# 2024-11-13 02:01:47,665 - root - INFO - Initially extracted target: 아래 요건을 모두 충족하는 자 고령군 거주 또는 거주 예정인 18세 이상 45세 청년 청년 1인가구 또는 청년 신혼부부(혼인신고일 7년 이내) 임차보증금 5천만원 이하이면서 월세 50만원 이하의 주택에 월세로 거주하는 전국 기준 무주택자 가구당 기준 중위소득 180% 이하 최대 10개월 간 1인 월 최대 10만원 지원 고령군청 인구정책과 청년정책팀(054 950 6589)
# 2024-11-13 02:01:47,666 - root - INFO - Final target value: 아래 요건을 모두 충족하는 자 고령군 거주 또는 거주 예정인 18세 이상 45세 청년 청년 1인가구 또는 청년 신혼부부(혼인신고일 7년 이내) 임차보증금 5천만원 이하이면서 월세 50만원 이하의 주택에 월세로 거주하는 전국 기준 무주택자 가구당 기준 중위소득 180% 이하 최대 10개월 간 1인 월 최대 10만원 지원 고령군청 인구정책과 청년정책팀(054 950 6589)
# 2024-11-13 02:01:47,668 - root - INFO - Processing row idx: 58
# 2024-11-13 02:01:47,670 - root - INFO - Original target: None
# 2024-11-13 02:01:47,671 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,671 - root - INFO - Using original target:
# 2024-11-13 02:01:47,672 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,673 - root - INFO - Using cleaned subject as target: 사업내용 해양바이오 전문혁신인재 양성을 위한 현장실습과정 운영 현장실습(해양관련 실험 및 장비사용법 등)을 통한 체험교육 (현장견학교육, 전문가초청강연(세미나) 등)
# 2024-11-13 02:01:47,673 - root - INFO - Final target value: 사업내용 해양바이오 전문혁신인재 양성을 위한 현장실습과정 운영 현장실습(해양관련 실험 및 장비사용법 등)을 통한 체험교육 (현장견학교육, 전문가초청강연(세미나) 등)
# 2024-11-13 02:01:47,674 - root - INFO - Processing row idx: 59
# 2024-11-13 02:01:47,675 - root - INFO - Original target: None
# 2024-11-13 02:01:47,676 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,677 - root - INFO - Using original target:
# 2024-11-13 02:01:47,677 - root - INFO - After cleaning original target:
# ...
# 2024-11-13 02:01:47,878 - root - INFO - Processing row idx: 96
# 2024-11-13 02:01:47,879 - root - INFO - Original target: None
# 2024-11-13 02:01:47,879 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,880 - root - INFO - Using original target:
# 2024-11-13 02:01:47,881 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,881 - root - INFO - Using cleaned subject as target: ｢청년기본법｣상 청년(19~34세 이하)으로 부모님과 별도 거주하는 무주택자에 대하여 실제 납부하는 임대료를 최대 240만원(월 최대 20만원)까지 최대 12개월(회) 동안 매월 분할 지원
# 2024-11-13 02:01:47,882 - root - INFO - Final target value: ｢청년기본법｣상 청년(19~34세 이하)으로 부모님과 별도 거주하는 무주택자에 대하여 실제 납부하는 임대료를 최대 240만원(월 최대 20만원)까지 최대 12개월(회) 동안 매월 분할 지원
# 2024-11-13 02:01:47,883 - root - INFO - Processing row idx: 97
# 2024-11-13 02:01:47,884 - root - INFO - Original target: None
# 2024-11-13 02:01:47,884 - root - INFO - Initially extracted target: 19세~34세 부모님과 별도 거주하는 무주택 청년(1989. 1. 1. ~ 2005. 12. 31. 출생) (소득) 청년가구 기준 중위소득 60% 이하 및 원가구(청년가구+부·모) 기준 중위소득 100% 이하 청년 중위소득 1인기준 60% 1,337,067원, 원가구(청년+부모) 중위소득 100% 3인기준 4,714,657원 (재산) 청년가구 1억 2천 2백만원 이하 및 원가구 4억 7천만원 이하
# 2024-11-13 02:01:47,885 - root - INFO - Final target value: 19세~34세 부모님과 별도 거주하는 무주택 청년(1989. 1. 1. ~ 2005. 12. 31. 출생) (소득) 청년가구 기준 중위소득 60% 이하 및 원가구(청년가구+부·모) 기준 중위소득 100% 이하 청년 중위소득 1인기준 60% 1,337,067원, 원가구(청년+부모) 중위소득 100% 3인기준 4,714,657원 (재산) 청년가구 1억 2천 2백만원 이하 및 원가구 4억 7천만원 이하
# 2024-11-13 02:01:47,886 - root - INFO - Processing row idx: 98
# 2024-11-13 02:01:47,886 - root - INFO - Original target: None
# 2024-11-13 02:01:47,888 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,889 - root - INFO - Using original target:
# 2024-11-13 02:01:47,890 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,890 - root - INFO - Using cleaned subject as target: 스타트업 (6기) 지원내용 청년창업LAB 시설, 장비 권한 부여 및 무상 이용 창업자 아이디어 제품개발을 위한 1 1 기술지도 및 경영 멘토링 지원 청년창업지원 (15기) 청년창업자 임대공간 제공 창업교육 창업활동비 최대 12,000천원 지원
# 2024-11-13 02:01:47,891 - root - INFO - Final target value: 스타트업 (6기) 지원내용 청년창업LAB 시설, 장비 권한 부여 및 무상 이용 창업자 아이디어 제품개발을 위한 1 1 기술지도 및 경영 멘토링 지원 청년창업지원 (15기) 청년창업자 임대공간 제공 창업교육 창업활동비 최대 12,000천원 지원
# 2024-11-13 02:01:47,892 - root - INFO - Processing row idx: 99
# 2024-11-13 02:01:47,893 - root - INFO - Original target: None
# 2024-11-13 02:01:47,893 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,894 - root - INFO - Using original target:
# 2024-11-13 02:01:47,894 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,895 - root - INFO - Using cleaned subject as target: 신청자격 최소 5인 이상 19세 ~ 49세 이하의 청년단체 울진군에 주민등록상 주소를 두고 거주하고 있는 청년으로 구성 울진군 소재 기업 및 단체 등에서 활동하고 있는 청년으로 구성 지원분야 재능기부, 자기계발 및 스펙업, 자원봉사 등 관심 분야 지원규모 팀당 160만원 지원항목 모임비 활동(모임) 시 커뮤니티 구성원들이 사용하는 식·음료비 제작비 활동과 관련된 자료 및 물품 제작비 교육·문화비 활동과 관련된 도서구입, 영화, 연극, 전시 관람비, 타 시군구 이동 교통비 등 강습비 활동과 관련하여 전문적 학습이 필요한 경우 사용하는 비용 교통비 활동과 관련하여 타 시군구 이동이 필요한 경우의 교통비 소모품비 활동을 위한 소모성 물품 구입비 임차비 단기적으로 필요한 공간 및 물품 등 대여에 필요한 비용
# 2024-11-13 02:01:47,895 - root - INFO - Final target value: 신청자격 최소 5인 이상 19세 ~ 49세 이하의 청년단체 울진군에 주민등록상 주소를 두고 거주하고 있는 청년으로 구성 울진군 소재 기업 및 단체 등에서 활동하고 있는 청년으로 구성 지원분야 재능기부, 자기계발 및 스펙업, 자원봉사 등 관심 분야 지원규모 팀당 160만원 지원항목 모임비 활동(모임) 시 커뮤니티 구성원들이 사용하는 식·음료비 제작비 활동과 관련된 자료 및 물품 제작비 교육·문화비 활동과 관련된 도서구입, 영화, 연극, 전시 관람비, 타 시군구 이동 교통비 등 강습비 활동과 관련하여 전문적 학습이 필요한 경우 사용하는 비용 교통비 활동과 관련하여 타 시군구 이동이 필요한 경우의 교통비 소모품비 활동을 위한 소모성 물품 구입비 임차비 단기적으로 필요한 공간 및 물품 등 대여에 필요한 비용
# 2024-11-13 02:01:47,896 - root - INFO - Processing row idx: 100
# 2024-11-13 02:01:47,897 - root - INFO - Original target: None
# 2024-11-13 02:01:47,898 - root - INFO - Initially extracted target: 만18세 이상 만34세 이하 구직단념청년 (구미시 만39세 이하 모집인원 30%까지 가능) ▸구직단념청년 최근 6개월 이상 취업 및 교육·직업훈련 이력이 없고, 구직단념청년 문답표 21점 이상(만점 30점)인 만18~34세 청년 ▸자립준비청년 아동복지시설 등에서 보호받고 퇴소한 자 중 퇴소 5년 이내의 청년 또는 퇴소 대상자임에도 불구 퇴소일자를 연기한 청년 ▸청소년 쉼터 등 입·퇴소 청년 청소년쉼터에서 1년 이상 보호한 만18세 이상의 청년 ▸북한 이탈 청년 북한을 이탈한 자로서 만18~34세 청년 ▸지역특화 공통요건 충족이 안 되더라도 지원 필요성 인정받은 청년 (정원 내 30%) 구미시 청년기본조례 상 만39세 이하 청년 6개월 미만이더라도 특별한 사유로 휴학 중인 대학생, 폐업 자영업 청년 등 구직단념청년 등을 대상으로 맞춤형 프로그램을 통한 청년의 구직의욕 고취, 노동시장 참여 및 취업 촉진 지원 경북고용성장지원센터 ☎070 7705 3272 / 070 7704 7925
# 2024-11-13 02:01:47,899 - root - INFO - Final target value: 만18세 이상 만34세 이하 구직단념청년 (구미시 만39세 이하 모집인원 30%까지 가능) ▸구직단념청년 최근 6개월 이상 취업 및 교육·직업훈련 이력이 없고, 구직단념청년 문답표 21점 이상(만점 30점)인 만18~34세 청년 ▸자립준비청년 아동복지시설 등에서 보호받고 퇴소한 자 중 퇴소 5년 이내의 청년 또는 퇴소 대상자임에도 불구 퇴소일자를 연기한 청년 ▸청소년 쉼터 등 입·퇴소 청년 청소년쉼터에서 1년 이상 보호한 만18세 이상의 청년 ▸북한 이탈 청년 북한을 이탈한 자로서 만18~34세 청년 ▸지역특화 공통요건 충족이 안 되더라도 지원 필요성 인정받은 청년 (정원 내 30%) 구미시 청년기본조례 상 만39세 이하 청년 6개월 미만이더라도 특별한 사유로 휴학 중인 대학생, 폐업 자영업 청년 등 구직단념청년 등을 대상으로 맞춤형 프로그램을 통한 청년의 구직의욕 고취, 노동시장 참여 및 취업 촉진 지원 경북고용성장지원센터 ☎070 7705 3272 / 070 7704 7925
# 2024-11-13 02:01:47,900 - root - INFO - Processing row idx: 101
# 2024-11-13 02:01:47,901 - root - INFO - Original target: None
# 2024-11-13 02:01:47,902 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,903 - root - INFO - Using original target:
# 2024-11-13 02:01:47,904 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,906 - root - INFO - Using cleaned subject as target: 1. 청년근로자 자산형성 지원(2년 만기예금, 1,060만원+이자) 청년적립금 360만원(매월 15만원, 총 24회 적립) 지자체지원금 700만원(분기당 175만원, 총 4회 적립) 2. 청년근로자 장기재직 여부 및 거주지 확인을 통한 참여청년 관리 기업방문이나 유선확인을 통한 지속적인 사업 모니터링
# 2024-11-13 02:01:47,907 - root - INFO - Final target value: 1. 청년근로자 자산형성 지원(2년 만기예금, 1,060만원+이자) 청년적립금 360만원(매월 15만원, 총 24회 적립) 지자체지원금 700만원(분기당 175만원, 총 4회 적립) 2. 청년근로자 장기재직 여부 및 거주지 확인을 통한 참여청년 관리 기업방문이나 유선확인을 통한 지속적인 사업 모니터링
# 2024-11-13 02:01:47,908 - root - INFO - Processing row idx: 102
# 2024-11-13 02:01:47,910 - root - INFO - Original target: None
# 2024-11-13 02:01:47,911 - root - INFO - Initially extracted target: 으로 체계적인 지원 및 창업성공률 향상을 위한 지원 연락처 053) 819 3073~72 E Mail shlee@gbtp. r.kr
# 2024-11-13 02:01:47,912 - root - INFO - Final target value: 으로 체계적인 지원 및 창업성공률 향상을 위한 지원 연락처 053) 819 3073~72 E Mail shlee@gbtp. r.kr
# 2024-11-13 02:01:47,913 - root - INFO - Processing row idx: 103
# 2024-11-13 02:01:47,914 - root - INFO - Original target: None
# 2024-11-13 02:01:47,916 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,917 - root - INFO - Using original target:
# 2024-11-13 02:01:47,918 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,919 - root - INFO - Using cleaned subject as target: 공 고 일 2. 2.(금) 17시 이후(LH청약플러스 홈페이지) 접 수 ∙ 온 라 인 2. 19.(월) ~ 2. 23(금) ∙ 현장접수 2. 20.(화) 10시 ~ 16시 LH경북서부권주거복지지사(송정동 행정복지센터 맞은편)
# 2024-11-13 02:01:47,921 - root - INFO - Final target value: 공 고 일 2. 2.(금) 17시 이후(LH청약플러스 홈페이지) 접 수 ∙ 온 라 인 2. 19.(월) ~ 2. 23(금) ∙ 현장접수 2. 20.(화) 10시 ~ 16시 LH경북서부권주거복지지사(송정동 행정복지센터 맞은편)
# 2024-11-13 02:01:47,922 - root - INFO - Processing row idx: 104
# 2024-11-13 02:01:47,923 - root - INFO - Original target: None
# 2024-11-13 02:01:47,925 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,926 - root - INFO - Using original target:
# 2024-11-13 02:01:47,927 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,929 - root - INFO - Using cleaned subject as target: 자세한 사항은 반드시 공고문 참고 가. 신청기간 2024. 1. 8. (월) ~ 예산 소진시까지 나. 지원자격 시험응시일 기준 1년 전부터 울진군에 주민등록 된 자로 19세 ~ 49세 청년 2023. 12. 1. 이후 시험 응시자 합격 여부와 무관 제 외 대 상 「국가재정법」, 「지방재정법」 또는 「지방자치단체 기금관리기본법」 등의 법률에 따른 회계 또는 기금에서 인건비가 지급되거나 보조되는 다음 각 호의 어느 하나에 해당하는 기관에 근무하는 자 1. 국가기관 및 지방자치단체 2. 「사립학교법」 제2조에 따른 사립학교 3. 「별정우체국법」 제2조에 따른 별정우체국 4. 「공공기관의 운영에 관한 법률」 제4조에 따른 공공기관 5. 「지방공기업법」제49조에 따른 지방공사 및 같은 법 제76조에 따른 지방공단 6. 「고등교육법」 제2조 각 호의 학교 중 국가가 국립대학 법인으로 설립하는 국립학교 다. 신청방법 오프라인 울진군청 일자리경제과 방문 또는 우편접수(등기) 주소지 읍면 사무소(산업팀) 방문 접수 온라인 청년e끌림 라. 제출서류 [서식1] 자격증 응시료 지원신청서 [서식2] 보조금 부정수급 관련 확약서 신청자 본인 명의 통장 사본 자격증 시험 응시사실 증명서류(해당시험 응시 확인서 등) 수험표, 접수증은 불가 자격증 응시 결제내역(입금 확인증 또는 신용카드 영수증 등) 주민등록초본(변동이력 포함 및 생년월일만 포함)
# 2024-11-13 02:01:47,930 - root - INFO - Final target value: 자세한 사항은 반드시 공고문 참고 가. 신청기간 2024. 1. 8. (월) ~ 예산 소진시까지 나. 지원자격 시험응시일 기준 1년 전부터 울진군에 주민등록 된 자로 19세 ~ 49세 청년 2023. 12. 1. 이후 시험 응시자 합격 여부와 무관 제 외 대 상 「국가재정법」, 「지방재정법」 또는 「지방자치단체 기금관리기본법」 등의 법률에 따른 회계 또는 기금에서 인건비가 지급되거나 보조되는 다음 각 호의 어느 하나에 해당하는 기관에 근무하는 자 1. 국가기관 및 지방자치단체 2. 「사립학교법」 제2조에 따른 사립학교 3. 「별정우체국법」 제2조에 따른 별정우체국 4. 「공공기관의 운영에 관한 법률」 제4조에 따른 공공기관 5. 「지방공기업법」제49조에 따른 지방공사 및 같은 법 제76조에 따른 지방공단 6. 「고등교육법」 제2조 각 호의 학교 중 국가가 국립대학 법인으로 설립하는 국립학교 다. 신청방법 오프라인 울진군청 일자리경제과 방문 또는 우편접수(등기) 주소지 읍면 사무소(산업팀) 방문 접수 온라인 청년e끌림 라. 제출서류 [서식1] 자격증 응시료 지원신청서 [서식2] 보조금 부정수급 관련 확약서 신청자 본인 명의 통장 사본 자격증 시험 응시사실 증명서류(해당시험 응시 확인서 등) 수험표, 접수증은 불가 자격증 응시 결제내역(입금 확인증 또는 신용카드 영수증 등) 주민등록초본(변동이력 포함 및 생년월일만 포함)
# 2024-11-13 02:01:47,931 - root - INFO - Processing row idx: 105
# 2024-11-13 02:01:47,933 - root - INFO - Original target: None
# 2024-11-13 02:01:47,935 - root - INFO - Initially extracted target: 자 최대500만원) > 1. 현직공무원 2. 사립학교 교직원 3. 졸업까지 수업연한이 2년을 초과하는 대학생 4. 연 매출 1억5천만원 이상 자영업자 5. 월임금 300만원 이상인 특수형태근로종사자 6. 월임금 300만원 이상이면서 45세 미만인 대규모기업종사자 등 발급처/문의처 직원훈련포탈(국번없이 1350 고용노동부 고객상담센터) 다. 지원내용 국민내일배움카드로 결제한 직업훈련비 중 자부담분 라.
# 2024-11-13 02:01:47,936 - root - INFO - Final target value: 자 최대500만원) > 1. 현직공무원 2. 사립학교 교직원 3. 졸업까지 수업연한이 2년을 초과하는 대학생 4. 연 매출 1억5천만원 이상 자영업자 5. 월임금 300만원 이상인 특수형태근로종사자 6. 월임금 300만원 이상이면서 45세 미만인 대규모기업종사자 등 발급처/문의처 직원훈련포탈(국번없이 1350 고용노동부 고객상담센터) 다. 지원내용 국민내일배움카드로 결제한 직업훈련비 중 자부담분 라.
# 2024-11-13 02:01:47,938 - root - INFO - Processing row idx: 106
# 2024-11-13 02:01:47,940 - root - INFO - Original target: None
# 2024-11-13 02:01:47,941 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,942 - root - INFO - Using original target:
# 2024-11-13 02:01:47,944 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,945 - root - INFO - Using cleaned subject as target: 청년 3.6백만원(매월 15만원, 총 24회 적립), 지자체 8백만원(분기당 100만원, 총 8회 적립)
# 2024-11-13 02:01:47,946 - root - INFO - Final target value: 청년 3.6백만원(매월 15만원, 총 24회 적립), 지자체 8백만원(분기당 100만원, 총 8회 적립)
# 2024-11-13 02:01:47,947 - root - INFO - Processing row idx: 107
# 2024-11-13 02:01:47,948 - root - INFO - Original target: None
# 2024-11-13 02:01:47,950 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,952 - root - INFO - Using original target:
# 2024-11-13 02:01:47,953 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,954 - root - INFO - Using cleaned subject as target: 창업교육 및 컨설팅, 창업활동비(최대 1,200만원) 지원
# 2024-11-13 02:01:47,955 - root - INFO - Final target value: 창업교육 및 컨설팅, 창업활동비(최대 1,200만원) 지원
# 2024-11-13 02:01:47,957 - root - INFO - Processing row idx: 108
# 2024-11-13 02:01:47,958 - root - INFO - Original target: None
# 2024-11-13 02:01:47,960 - root - INFO - Initially extracted target: 시험 응시료 실비 10만원 이내 지급(2024년 1월 1일 이후 응시분, 시험별 합산 가능) 사 업 량 어학·자격시험 응시료 지원 300명 정도(상반기 200명, 하반기 100명) 지원요건 ⦁ (연 령) 2024. 1. 1. 기준 만 19세 ~ 39세(1984. 1. 2. ~ 2005. 1. 1. 生)인 자 ⦁ (주민등록) 지원금 신청일 기준 주민등록상 안동시에 거주 중인 자 ⦁ (대상시험) 2024년 실시된 어학, 국가기술자격증, 국가전문자격증, 국가공인민간자격증, 한국사 대상시험( 상세한 사항은 붙임문서 별첨 청년 어학·자격시험 응시료 지원대상 시험 상세 참고) ⦁ (어학) 토익, 토익스피킹, 토플, 오픽, 텝스, 지텔프, 아이엘츠, 플렉스 등 ⦁ (국가기술자격증), (국가전문자격증) 「국가기술자격법」 시행규칙 [별표2]에 따른 국가기술자격 종목, 대한민국 정부 각 부처의 개별법에 따른 국가전문자격 종목 (확인절차) Q net 홈페이지 → 국가자격시험 → 자격정보 → 국가자격 → 국가자격종목별상세정보 → 국가기술자격 또는 국가전문자격 확인 ⦁ (국가공인민간자격증) 「자격기본법」 제19조(민간자격의 공인)에 따른 국가공인민간자격종목 (확인절차) 민간자격정보서비스(www.pqi. r.kr) → 공인 민간자격검색 ⦁ (한국사) 제출서류 붙임 사업계획서 참고 지원금 신청기간 ⦁ 상반기 5. 1.(수) 09 00 ~ 6. 30.(일) 18 00 (신청기간 이후 7월 중 제출서류 심사 및 지원금 지급) ⦁ 하반기 11. 1.(금) 09 00 ~ 11. 30.(토) 18 00 (신청기간 이후 12월 중 제출서류 심사 및 지원금 지급) 청년층의 구직활동 및 역량 강화에 필요한 어학·자격시험 응시료 지원으로 청년 구직자의 경제적 부담 완화 및 취업 능력 개발 지원 안동시청 인구정책과(054 840 6242)
# 2024-11-13 02:01:47,961 - root - INFO - Final target value: 시험 응시료 실비 10만원 이내 지급(2024년 1월 1일 이후 응시분, 시험별 합산 가능) 사 업 량 어학·자격시험 응시료 지원 300명 정도(상반기 200명, 하반기 100명) 지원요건 ⦁ (연 령) 2024. 1. 1. 기준 만 19세 ~ 39세(1984. 1. 2. ~ 2005. 1. 1. 生)인 자 ⦁ (주민등록) 지원금 신청일 기준 주민등록상 안동시에 거주 중인 자 ⦁ (대상시험) 2024년 실시된 어학, 국가기술자격증, 국가전문자격증, 국가공인민간자격증, 한국사 대상시험( 상세한 사항은 붙임문서 별첨 청년 어학·자격시험 응시료 지원대상 시험 상세 참고) ⦁ (어학) 토익, 토익스피킹, 토플, 오픽, 텝스, 지텔프, 아이엘츠, 플렉스 등 ⦁ (국가기술자격증), (국가전문자격증) 「국가기술자격법」 시행규칙 [별표2]에 따른 국가기술자격 종목, 대한민국 정부 각 부처의 개별법에 따른 국가전문자격 종목 (확인절차) Q net 홈페이지 → 국가자격시험 → 자격정보 → 국가자격 → 국가자격종목별상세정보 → 국가기술자격 또는 국가전문자격 확인 ⦁ (국가공인민간자격증) 「자격기본법」 제19조(민간자격의 공인)에 따른 국가공인민간자격종목 (확인절차) 민간자격정보서비스(www.pqi. r.kr) → 공인 민간자격검색 ⦁ (한국사) 제출서류 붙임 사업계획서 참고 지원금 신청기간 ⦁ 상반기 5. 1.(수) 09 00 ~ 6. 30.(일) 18 00 (신청기간 이후 7월 중 제출서류 심사 및 지원금 지급) ⦁ 하반기 11. 1.(금) 09 00 ~ 11. 30.(토) 18 00 (신청기간 이후 12월 중 제출서류 심사 및 지원금 지급) 청년층의 구직활동 및 역량 강화에 필요한 어학·자격시험 응시료 지원으로 청년 구직자의 경제적 부담 완화 및 취업 능력 개발 지원 안동시청 인구정책과(054 840 6242)
# 2024-11-13 02:01:47,963 - root - INFO - Processing row idx: 109
# 2024-11-13 02:01:47,964 - root - INFO - Original target: None
# 2024-11-13 02:01:47,966 - root - INFO - Initially extracted target: 구미시 관내 주민등록이 되어 있는 만19세~39세이하 무주택 청년 입주권, 분양권은 주택 보유로 간주 연소득 45백만원 이하인 자 구미시에 거주하는 미혼 1인 가구 세대주 전·월세 임차보증금 2.5억원 이하이면서 전․월세 전환율 6.0%이하 구미시 소재의 주택(단독, 공동) 및 준주택(오피스텔) 공공임대주택, 다중주택(기숙사), 불법건축물 지원 불가 지원
# 2024-11-13 02:01:47,967 - root - INFO - Final target value: 구미시 관내 주민등록이 되어 있는 만19세~39세이하 무주택 청년 입주권, 분양권은 주택 보유로 간주 연소득 45백만원 이하인 자 구미시에 거주하는 미혼 1인 가구 세대주 전·월세 임차보증금 2.5억원 이하이면서 전․월세 전환율 6.0%이하 구미시 소재의 주택(단독, 공동) 및 준주택(오피스텔) 공공임대주택, 다중주택(기숙사), 불법건축물 지원 불가 지원
# 2024-11-13 02:01:47,969 - root - INFO - Processing row idx: 110
# 2024-11-13 02:01:47,970 - root - INFO - Original target: None
# 2024-11-13 02:01:47,972 - root - INFO - Initially extracted target: 신청일 기준 보증 효력이 유효한 전세보증금반환보증(HUG, HF, SGI)에 가입한 임차보증금 3억원 이하, 연소득 ①(청년)5천만원, ②(청년 외)6천만원, ③(신혼부부)7.5천만원 이하 무주택 임차인
# 2024-11-13 02:01:47,973 - root - INFO - Final target value: 신청일 기준 보증 효력이 유효한 전세보증금반환보증(HUG, HF, SGI)에 가입한 임차보증금 3억원 이하, 연소득 ①(청년)5천만원, ②(청년 외)6천만원, ③(신혼부부)7.5천만원 이하 무주택 임차인
# 2024-11-13 02:01:47,975 - root - INFO - Processing row idx: 111
# 2024-11-13 02:01:47,976 - root - INFO - Original target: None
# 2024-11-13 02:01:47,978 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,979 - root - INFO - Using original target:
# 2024-11-13 02:01:47,980 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,982 - root - INFO - Using cleaned subject as target: ㅇ 신청자격 전입 직전 타시군구 1년 이상 주민등록 후 2023. 1. 30. 이후 구미로 전입오신 구미 소재 고등학교, 대학교 학생 대학원생, 휴학생, 졸업생 제외 ㅇ 지원내용 최대 40만원 학업장려금 지원 전입신고 후 6개월 경과 10만원 전입신고 후 12개월 경과 10만원 전입신고 후 1년 6개월 경과 10만원 전입신고 후 2년 경과 10만원
# 2024-11-13 02:01:47,983 - root - INFO - Final target value: ㅇ 신청자격 전입 직전 타시군구 1년 이상 주민등록 후 2023. 1. 30. 이후 구미로 전입오신 구미 소재 고등학교, 대학교 학생 대학원생, 휴학생, 졸업생 제외 ㅇ 지원내용 최대 40만원 학업장려금 지원 전입신고 후 6개월 경과 10만원 전입신고 후 12개월 경과 10만원 전입신고 후 1년 6개월 경과 10만원 전입신고 후 2년 경과 10만원
# 2024-11-13 02:01:47,984 - root - INFO - Processing row idx: 112
# 2024-11-13 02:01:47,985 - root - INFO - Original target: None
# 2024-11-13 02:01:47,985 - root - INFO - Initially extracted target:
# 2024-11-13 02:01:47,986 - root - INFO - Using original target:
# 2024-11-13 02:01:47,987 - root - INFO - After cleaning original target:
# 2024-11-13 02:01:47,988 - root - INFO - Using cleaned subject as target: 음료 모바일 포인트 1인당 7만원 상당(쿠폰형태) 사용용도 음료구입 (꿈이음카페 방문시 음료 사용료 차감) 지원규모 7만 포인트 지급 (2회에 나누어 지급) (1차) 개인별 4만 포인트 지급 (2차) 1차 포인트 80% 이상 소진 및 취·창업 프로그램 2회 참여자에게 추가 3만포인트 지급 취·창업 프로그램 3회 이상 (카페프로그램 1회 필수) 참여 참여 활동 종료 후 참여 후기 제출
# 2024-11-13 02:01:47,988 - root - INFO - Final target value: 음료 모바일 포인트 1인당 7만원 상당(쿠폰형태) 사용용도 음료구입 (꿈이음카페 방문시 음료 사용료 차감) 지원규모 7만 포인트 지급 (2회에 나누어 지급) (1차) 개인별 4만 포인트 지급 (2차) 1차 포인트 80% 이상 소진 및 취·창업 프로그램 2회 참여자에게 추가 3만포인트 지급 취·창업 프로그램 3회 이상 (카페프로그램 1회 필수) 참여 참여 활동 종료 후 참여 후기 제출
# 2024-11-13 02:01:47,990 - root - INFO - Successfully processed 111 records
# 2024-11-13 02:01:50,442 - root - INFO - Successfully saved 111 records to policy_detail_cleaned
# 2024-11-13 02:01:50,443 - root - INFO - Data processing completed successfully

# %%
ET = datetime.now()
print(ET-ST)
# Out:
# 2:12:19.629581
